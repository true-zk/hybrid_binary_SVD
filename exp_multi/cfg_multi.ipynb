# %% [markdown]
# ### CFG model for multiple detect
# - load dataset
# - train model

# %%
import os
import gc
import time
import random
import pickle
import math
import numpy as np
import torch
import torch.nn as nn
from torch.nn import Linear
import torch.nn.functional as F
from torch.utils.data import DataLoader as Dataloader_dsm, Dataset
from torch_geometric.loader import DataLoader as Dataloader_dot
from torch_geometric.nn import MessagePassing, TopKPooling
from torch_geometric.nn import global_mean_pool, global_max_pool
from torch_geometric.utils import degree

from sklearn.metrics import classification_report
import matplotlib.pyplot as plt

# %%
# GCN layer
# cite: https://pytorch-geometric.readthedocs.io/en/latest/notes/create_gnn.html
class GCNConv(MessagePassing):
    def __init__(self, in_channels, out_channels, **kwargs):
        super().__init__(aggr='add', **kwargs)  # "Add" aggregation (Step 5).
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.lin = Linear(in_channels, out_channels)

    def forward(self, x, edge_index):
        # x[N, in_channels]
        # edge_index, _ = add_self_loops(edge_index, num_nodes=x.size(0))
        x = self.lin(x)
        row, col = edge_index

        deg = degree(col, x.size(0), dtype=x.dtype)

        deg_inv_sqrt = deg.pow(-0.5)
        deg_inv_sqrt[deg_inv_sqrt == float('inf')] = 0
        norm = deg_inv_sqrt[row] * deg_inv_sqrt[col]
        return  self.propagate(edge_index, size=(x.size(0), x.size(0)), x=x, norm=norm)

    def message(self, x_j, norm):
        # x_j has shape [E, out_channels]

        # Step 4: Normalize node features.
        return norm.view(-1, 1) * x_j

    def update(self, aggr_out):
        # aggr_out has shape [N, out_channels]
        # Step 6: Return new node embeddings.
        return aggr_out

# %%
class CFGNet(torch.nn.Module):
	def __init__(self, size0=175, size1=45):
		super(CFGNet, self).__init__()
		###############################################################################
		# GCN model   																  #
		###############################################################################
		self.conv1 = GCNConv(256, 256)
		self.pool1 = TopKPooling(256, ratio=0.8)
		self.conv2 = GCNConv(256, 256)
		self.pool2 = TopKPooling(256, ratio=0.8)
		self.conv3 = GCNConv(256, 256)
		self.pool3 = TopKPooling(256, ratio=0.8)
		self.conv4 = GCNConv(256, 256)
		self.pool4 = TopKPooling(256, ratio=0.8)
		self.conv5 = GCNConv(256, 256)
		self.pool5 = TopKPooling(256, ratio=0.8)

		self.convAtt1 = torch.nn.Conv1d(in_channels=512, out_channels=64, kernel_size=1, stride=2)
		self.poolAtt1 = torch.nn.MaxPool1d(kernel_size=1, stride=2)
		self.convAtt2 = torch.nn.Conv1d(64, 16, kernel_size=1, stride=2)
		self.poolAtt2 = torch.nn.MaxPool1d(kernel_size=1, stride=2)
		self.convAtt3 = torch.nn.Conv1d(16, 2, kernel_size=1, stride=2)
		self.poolAtt3 = torch.nn.MaxPool1d(kernel_size=1, stride=2)

		self.convAtt4 = torch.nn.Conv1d(2, 16, kernel_size=1, stride=2)
		self.poolAtt4 = torch.nn.MaxPool1d(kernel_size=1, stride=2)
		self.convAtt5 = torch.nn.Conv1d(16, 64, kernel_size=1, stride=2)
		self.poolAtt5 = torch.nn.MaxPool1d(kernel_size=1, stride=2)
		self.convAtt6 = torch.nn.Conv1d(64, 512, kernel_size=1, stride=2)
		self.poolAtt6 = torch.nn.MaxPool1d(kernel_size=1, stride=2)

		###############################################################################
		# textCNN model   															  #
		###############################################################################
		# h_input = size0
		# w_input = size1
		# filter_list = [2, 4, 6, 8, 10, 12, 16, 20]
		# num_per_filter = 64
		# h_raw = [h_input - i + 1 for i in filter_list]  # 175-filter_size+1: after conv
		# filter_list1 = [math.ceil(i / 2) for i in h_raw]  # p = ceil[h_raw / 2]
		# self.num_filter = len(filter_list)
		# self.conv_t = nn.ModuleList([nn.Conv2d(1, num_per_filter, (cnv_size, w_input)) for cnv_size in filter_list])
		# self.max_t = nn.MaxPool2d(kernel_size=(num_per_filter, 1))
		# self.avg_t = nn.AvgPool2d(kernel_size=(num_per_filter, 1))
		# self.conv_t1 = nn.ModuleList([nn.Conv2d(2, 1, (cnv_size, 1), padding='same') for cnv_size in filter_list1])
		# self.sig = nn.Sigmoid()
		# h_res = sum(h_raw)  # textCNN_input_feature
		# self.lin0_ = torch.nn.Linear(h_res, 512)
		###############################################################################
		# hybrid output   															  #
		###############################################################################
		# x: cfg  t:dsm
		# self.ratio = 0.5
		# r_dot = round(self.ratio * 1024)
		# r_dsm = 1024 - r_dot
        #
		# self.lin0x_ = torch.nn.Linear(512, r_dot)
		# self.lin0t_ = torch.nn.Linear(512, r_dsm)

		# self.lin1_ = torch.nn.Linear(1024, 512)
		self.lin2_ = torch.nn.Linear(512, 128)
		self.lin3_ = torch.nn.Linear(128, 64)
		self.lin4_ = torch.nn.Linear(64, 6)
		self.dropout_ = nn.Dropout(0.6)

	def forward(self, x, edge_index, batch):
		###############################################################################
		# GCN model :  x, edge_index, batch = data.x, data.edge_index, data.batch	  #
		###############################################################################
		x = F.relu(self.conv1(x, edge_index))
		x, edge_index, _, batch, _, _ = self.pool1(x, edge_index, None, batch)
		x1 = torch.cat([global_max_pool(x, batch), global_mean_pool(x, batch)], dim=1)

		x = F.relu(self.conv2(x, edge_index))
		x, edge_index, _, batch, _, _ = self.pool2(x, edge_index, None, batch)
		x2 = torch.cat([global_max_pool(x, batch), global_mean_pool(x, batch)], dim=1)

		x = F.relu(self.conv3(x, edge_index))
		x, edge_index, _, batch, _, _ = self.pool3(x, edge_index, None, batch)
		x3 = torch.cat([global_max_pool(x, batch), global_mean_pool(x, batch)], dim=1)

		x = F.relu(self.conv4(x, edge_index))
		x, edge_index, _, batch, _, _ = self.pool4(x, edge_index, None, batch)
		x4 = torch.cat([global_max_pool(x, batch), global_mean_pool(x, batch)], dim=1)

		x = F.relu(self.conv5(x, edge_index))
		x, edge_index, _, batch, _, _ = self.pool5(x, edge_index, None, batch)
		x5 = torch.cat([global_max_pool(x, batch), global_mean_pool(x, batch)], dim=1)

		x = x1 + x2 + x3 + x4 + x5

		x = 1 / 5 * x

		sx = x

		x = x.unsqueeze(dim=2)

		# attention
		x = F.relu(self.convAtt1(x))
		x = self.poolAtt1(x)
		x = F.relu(self.convAtt2(x))
		x = self.poolAtt2(x)
		x = F.relu(self.convAtt3(x))
		x = self.poolAtt3(x)

		x = F.relu(self.convAtt4(x))
		x = self.poolAtt4(x)
		x = F.relu(self.convAtt5(x))
		x = self.poolAtt5(x)
		x = F.relu(self.convAtt6(x))
		x = self.poolAtt6(x)
		x = x.squeeze()

		x = (x + 1) * sx

		###############################################################################
		# TextCNN model :  t = batch * h * w										  #
		###############################################################################
		# t = torch.unsqueeze(t, 1)
		# t = [torch.squeeze(F.relu(conv(t)), 3) for conv in self.conv_t]
		# # per_filter * [batch * num_per_filter * h_raw]
		#
		# for i in range(0, self.num_filter):
		# 	t[i] = torch.unsqueeze(t[i], 1)
		# 	# [batch * 1 * num_per_filter * h_raw]
		# 	max_ = torch.unsqueeze(torch.squeeze(self.max_t(t[i]), 1), 3)
		# 	avg_ = torch.unsqueeze(torch.squeeze(self.avg_t(t[i]), 1), 3)
		#
		# 	attention_ = torch.cat((max_, avg_), dim=1)
		# 	attention_ = self.sig(self.conv_t1[i](attention_))
		# 	attention_ = torch.unsqueeze(torch.squeeze(attention_, 3), 1)
		# 	t[i] = t[i] * attention_
		# 	t[i] = torch.squeeze(self.max_t(t[i]))
		# t = torch.cat(t, dim=1)
		# t = torch.squeeze(t)
		# t = F.relu(self.lin0_(t))
		###############################################################################
		# hybrid output :  #
		###############################################################################
		# out layer
		# self.lin0x_ = torch.nn.Linear(512, r_dot)
		# self.lin0t_ = torch.nn.Linear(512, r_dsm)
        # if self.ratio != 0.5:
		#   x = F.relu(self.lin0x_(x))
		#   t = F.relu(self.lin0t_(t))

		# x = torch.cat((x, t), dim=1)  # 512 + 512

		# x = F.relu(self.lin1_(x))
		x = F.relu(self.lin2_(x))
		x = F.relu(self.lin3_(x))
		x = F.dropout(x, p=0.5, training=self.training)
		x = F.log_softmax(self.lin4_(x), dim=-1)

		return x

# %%
class MyDataset(Dataset):
    def __init__(self, dataset_, size_):
        for idx, data_ in enumerate(dataset_):
            data_len_ = len(data_)
            if data_len_ < size_[0]:
                pad = torch.zeros(size_[0] - data_len_, size_[1])
                dataset_[idx] = torch.cat((data_, pad), dim=0)
            else:
                dataset_[idx] = data_[:size_[0]]
        self.dateset = dataset_
        self.size = size_

    def __len__(self):
        return len(self.dateset)

    def __getitem__(self, idx):
        return self.dateset[idx]

# %%
# init model
size_ = [175, 45]
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = CFGNet().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
def train(Train_dot_loader, Train_dsm_loader):
	model.train()
	loss_all = 0
	iter_loader = iter(Train_dsm_loader)
	for data in Train_dot_loader:
		data1 = next(iter_loader)
		data1 = data1.to(device)
		data = data.to(device)

		optimizer.zero_grad()

		x, edge_index, batch = data.x, data.edge_index, data.batch
		output = model(x, edge_index, batch)
		loss = F.nll_loss(output, data.y) # 32*6 -> 32*1
		loss.backward()
		loss_all += data.num_graphs * loss.item()
		optimizer.step()
	return loss_all / len(Train_dot_loader.dataset)

# %%
def test(loader0, loader1):
	# loader0:dot loader1:dsm
	model.eval()
	correct = 0
	iter_loader = iter(loader1)
	pred_list, true_list = np.array(0), np.array(0)
	for data0 in loader0:
		data1 = next(iter_loader)
		data1 = data1.to(device)
		data0 = data0.to(device)
		optimizer.zero_grad()
		x, edge_index, batch = data0.x, data0.edge_index, data0.batch
		y_pred = model(x, edge_index, batch)
		y_pred = y_pred.max(dim=1)[1]
		pred_list = np.append(pred_list, y_pred.to('cpu').numpy())
		true_list = np.append(true_list, data0.y.to('cpu').numpy())
		correct += y_pred.eq(data0.y).sum().item()
	acc = correct / len(loader0.dataset)
	return round(acc, 6), pred_list, true_list

# %%
# main:
start_time = time.time()

with open(rf'D:\Desktop\hybrid-SVD\dataset\multi_test.pk', 'rb') as f_:
	cur_dataset = pickle.load(f_)
	random.shuffle(cur_dataset)
	test_dsm = []
	test_dot = []
	for d in cur_dataset:
		test_dot.append(d[0])
		test_dsm.append(d[1])
	del cur_dataset
	gc.collect()
	Test_dot_loader = Dataloader_dot(test_dot, batch_size=32, shuffle=False, drop_last=True)
	Test_dsm_loader = Dataloader_dsm(MyDataset(test_dsm, size_), batch_size=32, shuffle=False, drop_last=True)

all_loss_list = []
avg_loss_list = []
acc_list = []
best_model = None
best_acc = {'acc': 0, 'epoch': 0}

for epoch in range(0, 80):
	print("===>epoch:{:03d}===>".format(epoch))
	loss_list = []
	for i_ in range(0, 4):
		with open(rf'D:\Desktop\hybrid-SVD\dataset\multi_train{i_}.pk', 'rb') as f_:
			cur_dataset = pickle.load(f_)
			random.shuffle(cur_dataset)
			train_dsm = []
			train_dot = []
			for d in cur_dataset:
				train_dot.append(d[0])
				train_dsm.append(d[1])
			del cur_dataset
			gc.collect()
			Train_dot_loader = Dataloader_dot(train_dot, batch_size=32, shuffle=False, drop_last=True)
			Train_dsm_loader = Dataloader_dsm(MyDataset(train_dsm, size_), batch_size=32, shuffle=False, drop_last=True)
			loss = train(Train_dot_loader, Train_dsm_loader)
			loss_list.append(loss)
			all_loss_list.append(loss)
			if epoch % 1 == 0:
				acc, _, _ = test(Train_dot_loader, Train_dsm_loader)
				print("#train_set:{:d}, loss:{:.5f}, Train_acc:{:.5f}".format(i_, loss, acc))
			if epoch % 1 == 0 and i_ == 3:
				avg_loss = math.fsum(loss_list) / 4
				avg_loss_list.append(avg_loss)
				print("avg loss:{:.5f}".format(avg_loss))

	if epoch % 1 == 0:
		acc, y_pred, y_true = test(Test_dot_loader, Test_dsm_loader)
		acc_list.append(acc)
		if acc > best_acc['acc']:
			best_acc['acc'], best_acc['epoch'] = acc, epoch
			best_model = model
		print("Test_acc:{:.5f}".format(acc))
		measure_result = classification_report(y_true[1:], y_pred[1:])
		print('measure_result = \n', measure_result)
		print("Time span:{:.5f}".format(time.time() - start_time))

print("Total time span:{:.5f}".format(time.time() - start_time))
# Out:
# ===>epoch:000===>
# #train_set:0, loss:1.35966, Train_acc:0.54375
# #train_set:1, loss:1.07627, Train_acc:0.59766
# #train_set:2, loss:0.94290, Train_acc:0.61289
# #train_set:3, loss:0.86664, Train_acc:0.62383
# avg loss:1.06137
# Test_acc:0.61700
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.92      0.58      0.71      1297
#            1       0.73      0.58      0.65       218
#            2       0.00      0.00      0.00       133
#            3       0.00      0.00      0.00       153
#            4       0.42      0.94      0.59       669
#            5       0.75      0.68      0.71       154
#
#     accuracy                           0.62      2624
#    macro avg       0.47      0.46      0.44      2624
# weighted avg       0.67      0.62      0.60      2624
#
# Time span:36.52488
# ===>epoch:001===>
# D:\Develop\Miniconda\envs\pytorch\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# D:\Develop\Miniconda\envs\pytorch\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# D:\Develop\Miniconda\envs\pytorch\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# #train_set:0, loss:0.81424, Train_acc:0.74141
# #train_set:1, loss:0.73901, Train_acc:0.73867
# #train_set:2, loss:0.63283, Train_acc:0.75430
# #train_set:3, loss:0.60678, Train_acc:0.79453
# avg loss:0.69822
# Test_acc:0.77515
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.83      0.83      0.83      1297
#            1       0.98      0.81      0.89       218
#            2       0.00      0.00      0.00       133
#            3       0.40      0.42      0.41       153
#            4       0.73      0.90      0.80       669
#            5       0.85      0.73      0.78       154
#
#     accuracy                           0.78      2624
#    macro avg       0.63      0.61      0.62      2624
# weighted avg       0.75      0.78      0.76      2624
#
# Time span:66.83821
# ===>epoch:002===>
# #train_set:0, loss:0.60535, Train_acc:0.78594
# #train_set:1, loss:0.57402, Train_acc:0.80078
# #train_set:2, loss:0.54944, Train_acc:0.79727
# #train_set:3, loss:0.49665, Train_acc:0.81328
# avg loss:0.55637
# Test_acc:0.77934
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.86      0.80      0.83      1297
#            1       0.89      0.89      0.89       218
#            2       0.59      0.12      0.20       133
#            3       0.38      0.27      0.32       153
#            4       0.69      0.97      0.81       669
#            5       0.88      0.69      0.78       154
#
#     accuracy                           0.78      2624
#    macro avg       0.72      0.62      0.64      2624
# weighted avg       0.78      0.78      0.76      2624
#
# Time span:98.77701
# ===>epoch:003===>
# #train_set:0, loss:0.49771, Train_acc:0.80430
# #train_set:1, loss:0.50092, Train_acc:0.79688
# #train_set:2, loss:0.47935, Train_acc:0.79805
# #train_set:3, loss:0.45553, Train_acc:0.79375
# avg loss:0.48338
# Test_acc:0.76143
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.82      0.80      0.81      1297
#            1       0.90      0.88      0.89       218
#            2       0.44      0.05      0.09       133
#            3       0.22      0.07      0.10       153
#            4       0.67      0.99      0.80       669
#            5       0.95      0.61      0.74       154
#
#     accuracy                           0.76      2624
#    macro avg       0.67      0.57      0.57      2624
# weighted avg       0.74      0.76      0.73      2624
#
# Time span:127.86208
# ===>epoch:004===>
# #train_set:0, loss:0.44760, Train_acc:0.82656
# #train_set:1, loss:0.43680, Train_acc:0.81367
# #train_set:2, loss:0.42705, Train_acc:0.80234
# #train_set:3, loss:0.42120, Train_acc:0.82734
# avg loss:0.43316
# Test_acc:0.79649
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.79      0.87      0.83      1297
#            1       0.98      0.87      0.92       218
#            2       0.71      0.11      0.19       133
#            3       0.55      0.37      0.44       153
#            4       0.80      0.84      0.82       669
#            5       0.78      0.88      0.83       154
#
#     accuracy                           0.80      2624
#    macro avg       0.77      0.66      0.67      2624
# weighted avg       0.79      0.80      0.78      2624
#
# Time span:156.84457
# ===>epoch:005===>
# #train_set:0, loss:0.39470, Train_acc:0.80977
# #train_set:1, loss:0.41784, Train_acc:0.81211
# #train_set:2, loss:0.38202, Train_acc:0.81680
# #train_set:3, loss:0.38456, Train_acc:0.81758
# avg loss:0.39478
# Test_acc:0.79649
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.96      0.75      0.84      1297
#            1       0.96      0.90      0.93       218
#            2       0.33      0.20      0.25       133
#            3       0.41      0.82      0.54       153
#            4       0.74      0.94      0.83       669
#            5       0.85      0.88      0.86       154
#
#     accuracy                           0.80      2624
#    macro avg       0.71      0.75      0.71      2624
# weighted avg       0.83      0.80      0.80      2624
#
# Time span:186.15963
# ===>epoch:006===>
# #train_set:0, loss:0.39068, Train_acc:0.82734
# #train_set:1, loss:0.38786, Train_acc:0.82109
# #train_set:2, loss:0.39196, Train_acc:0.83672
# #train_set:3, loss:0.39321, Train_acc:0.84102
# avg loss:0.39093
# Test_acc:0.81479
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.90      0.80      0.85      1297
#            1       0.96      0.90      0.93       218
#            2       0.70      0.23      0.34       133
#            3       0.49      0.64      0.55       153
#            4       0.74      0.95      0.83       669
#            5       0.83      0.92      0.87       154
#
#     accuracy                           0.81      2624
#    macro avg       0.77      0.74      0.73      2624
# weighted avg       0.83      0.81      0.81      2624
#
# Time span:216.67944
# ===>epoch:007===>
# #train_set:0, loss:0.36851, Train_acc:0.84961
# #train_set:1, loss:0.37174, Train_acc:0.83711
# #train_set:2, loss:0.36920, Train_acc:0.83398
# #train_set:3, loss:0.37215, Train_acc:0.83984
# avg loss:0.37040
# Test_acc:0.84261
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.81      0.96      0.88      1297
#            1       1.00      0.87      0.93       218
#            2       0.65      0.50      0.56       133
#            3       0.60      0.44      0.51       153
#            4       0.93      0.76      0.84       669
#            5       1.00      0.85      0.92       154
#
#     accuracy                           0.84      2624
#    macro avg       0.83      0.73      0.77      2624
# weighted avg       0.85      0.84      0.84      2624
#
# Time span:247.45961
# ===>epoch:008===>
# #train_set:0, loss:0.35375, Train_acc:0.84375
# #train_set:1, loss:0.36513, Train_acc:0.83320
# #train_set:2, loss:0.34599, Train_acc:0.79648
# #train_set:3, loss:0.35354, Train_acc:0.83008
# avg loss:0.35460
# Test_acc:0.80755
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.91      0.79      0.85      1297
#            1       0.88      0.99      0.93       218
#            2       0.77      0.17      0.28       133
#            3       0.49      0.44      0.47       153
#            4       0.69      0.97      0.81       669
#            5       0.90      0.95      0.92       154
#
#     accuracy                           0.81      2624
#    macro avg       0.77      0.72      0.71      2624
# weighted avg       0.82      0.81      0.80      2624
#
# Time span:278.00766
# ===>epoch:009===>
# #train_set:0, loss:0.34717, Train_acc:0.85859
# #train_set:1, loss:0.35951, Train_acc:0.84844
# #train_set:2, loss:0.35938, Train_acc:0.83828
# #train_set:3, loss:0.32443, Train_acc:0.86016
# avg loss:0.34762
# Test_acc:0.82736
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.85      0.86      0.86      1297
#            1       0.97      0.90      0.93       218
#            2       0.60      0.51      0.55       133
#            3       0.64      0.36      0.46       153
#            4       0.78      0.89      0.83       669
#            5       0.92      0.94      0.93       154
#
#     accuracy                           0.83      2624
#    macro avg       0.79      0.74      0.76      2624
# weighted avg       0.82      0.83      0.82      2624
#
# Time span:309.59959
# ===>epoch:010===>
# #train_set:0, loss:0.33422, Train_acc:0.85195
# #train_set:1, loss:0.32497, Train_acc:0.85117
# #train_set:2, loss:0.31985, Train_acc:0.85547
# #train_set:3, loss:0.33185, Train_acc:0.85664
# avg loss:0.32772
# Test_acc:0.83270
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.88      0.82      0.85      1297
#            1       0.95      0.95      0.95       218
#            2       0.69      0.53      0.60       133
#            3       0.68      0.50      0.58       153
#            4       0.74      0.94      0.83       669
#            5       0.99      0.88      0.93       154
#
#     accuracy                           0.83      2624
#    macro avg       0.82      0.77      0.79      2624
# weighted avg       0.84      0.83      0.83      2624
#
# Time span:340.65816
# ===>epoch:011===>
# #train_set:0, loss:0.30953, Train_acc:0.85664
# #train_set:1, loss:0.33189, Train_acc:0.84258
# #train_set:2, loss:0.31362, Train_acc:0.85664
# #train_set:3, loss:0.30209, Train_acc:0.86133
# avg loss:0.31429
# Test_acc:0.83842
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.92      0.80      0.86      1297
#            1       0.89      1.00      0.94       218
#            2       0.68      0.66      0.67       133
#            3       0.64      0.50      0.56       153
#            4       0.75      0.94      0.83       669
#            5       0.96      0.94      0.95       154
#
#     accuracy                           0.84      2624
#    macro avg       0.81      0.81      0.80      2624
# weighted avg       0.85      0.84      0.84      2624
#
# Time span:371.42897
# ===>epoch:012===>
# #train_set:0, loss:0.32576, Train_acc:0.85000
# #train_set:1, loss:0.31955, Train_acc:0.85469
# #train_set:2, loss:0.31092, Train_acc:0.85352
# #train_set:3, loss:0.29691, Train_acc:0.85977
# avg loss:0.31329
# Test_acc:0.84184
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.88      0.85      0.87      1297
#            1       0.89      1.00      0.94       218
#            2       0.63      0.68      0.65       133
#            3       0.68      0.50      0.58       153
#            4       0.80      0.87      0.83       669
#            5       0.96      0.93      0.94       154
#
#     accuracy                           0.84      2624
#    macro avg       0.81      0.80      0.80      2624
# weighted avg       0.84      0.84      0.84      2624
#
# Time span:402.22885
# ===>epoch:013===>
# #train_set:0, loss:0.31892, Train_acc:0.85508
# #train_set:1, loss:0.30662, Train_acc:0.85313
# #train_set:2, loss:0.29793, Train_acc:0.86094
# #train_set:3, loss:0.32300, Train_acc:0.82344
# avg loss:0.31162
# Test_acc:0.81479
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.82      0.92      0.87      1297
#            1       1.00      0.87      0.93       218
#            2       0.60      0.35      0.44       133
#            3       0.50      0.59      0.54       153
#            4       0.84      0.84      0.84       669
#            5       1.00      0.41      0.58       154
#
#     accuracy                           0.81      2624
#    macro avg       0.79      0.66      0.70      2624
# weighted avg       0.82      0.81      0.81      2624
#
# Time span:432.61886
# ===>epoch:014===>
# #train_set:0, loss:0.34237, Train_acc:0.84531
# #train_set:1, loss:0.31085, Train_acc:0.85117
# #train_set:2, loss:0.29979, Train_acc:0.86172
# #train_set:3, loss:0.30258, Train_acc:0.86641
# avg loss:0.31390
# Test_acc:0.84146
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.87      0.85      0.86      1297
#            1       1.00      0.87      0.93       218
#            2       0.75      0.60      0.67       133
#            3       0.79      0.53      0.64       153
#            4       0.76      0.91      0.83       669
#            5       0.94      0.95      0.94       154
#
#     accuracy                           0.84      2624
#    macro avg       0.85      0.78      0.81      2624
# weighted avg       0.85      0.84      0.84      2624
#
# Time span:463.98744
# ===>epoch:015===>
# #train_set:0, loss:0.29564, Train_acc:0.85859
# #train_set:1, loss:0.29640, Train_acc:0.86133
# #train_set:2, loss:0.29255, Train_acc:0.86562
# #train_set:3, loss:0.27716, Train_acc:0.86992
# avg loss:0.29044
# Test_acc:0.85518
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.86      0.87      0.87      1297
#            1       0.99      0.89      0.93       218
#            2       0.84      0.67      0.74       133
#            3       0.83      0.58      0.68       153
#            4       0.80      0.89      0.84       669
#            5       0.90      0.98      0.94       154
#
#     accuracy                           0.86      2624
#    macro avg       0.87      0.81      0.83      2624
# weighted avg       0.86      0.86      0.85      2624
#
# Time span:494.79322
# ===>epoch:016===>
# #train_set:0, loss:0.28008, Train_acc:0.87109
# #train_set:1, loss:0.29409, Train_acc:0.86875
# #train_set:2, loss:0.32737, Train_acc:0.86602
# #train_set:3, loss:0.28942, Train_acc:0.86992
# avg loss:0.29774
# Test_acc:0.84299
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.89      0.82      0.85      1297
#            1       0.98      0.89      0.93       218
#            2       0.91      0.59      0.71       133
#            3       0.63      0.74      0.68       153
#            4       0.76      0.93      0.84       669
#            5       0.96      0.92      0.94       154
#
#     accuracy                           0.84      2624
#    macro avg       0.85      0.81      0.83      2624
# weighted avg       0.85      0.84      0.84      2624
#
# Time span:525.93940
# ===>epoch:017===>
# #train_set:0, loss:0.28194, Train_acc:0.86484
# #train_set:1, loss:0.27154, Train_acc:0.86133
# #train_set:2, loss:0.28437, Train_acc:0.87109
# #train_set:3, loss:0.27478, Train_acc:0.87656
# avg loss:0.27816
# Test_acc:0.85442
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.87      0.86      0.86      1297
#            1       0.98      0.89      0.93       218
#            2       0.89      0.61      0.72       133
#            3       0.85      0.61      0.71       153
#            4       0.77      0.92      0.84       669
#            5       1.00      0.93      0.96       154
#
#     accuracy                           0.85      2624
#    macro avg       0.89      0.80      0.84      2624
# weighted avg       0.86      0.85      0.85      2624
#
# Time span:555.61731
# ===>epoch:018===>
# #train_set:0, loss:0.26704, Train_acc:0.87852
# #train_set:1, loss:0.27866, Train_acc:0.86641
# #train_set:2, loss:0.26982, Train_acc:0.86680
# #train_set:3, loss:0.28193, Train_acc:0.87148
# avg loss:0.27436
# Test_acc:0.84832
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.90      0.82      0.85      1297
#            1       1.00      0.87      0.93       218
#            2       0.89      0.65      0.75       133
#            3       0.77      0.71      0.73       153
#            4       0.74      0.96      0.83       669
#            5       0.96      0.94      0.95       154
#
#     accuracy                           0.85      2624
#    macro avg       0.87      0.82      0.84      2624
# weighted avg       0.86      0.85      0.85      2624
#
# Time span:585.37906
# ===>epoch:019===>
# #train_set:0, loss:0.27655, Train_acc:0.87617
# #train_set:1, loss:0.27718, Train_acc:0.86836
# #train_set:2, loss:0.29521, Train_acc:0.87500
# #train_set:3, loss:0.28139, Train_acc:0.86680
# avg loss:0.28258
# Test_acc:0.84375
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.88      0.84      0.86      1297
#            1       1.00      0.82      0.90       218
#            2       0.99      0.51      0.67       133
#            3       0.80      0.60      0.69       153
#            4       0.74      0.97      0.84       669
#            5       0.96      0.95      0.95       154
#
#     accuracy                           0.84      2624
#    macro avg       0.89      0.78      0.82      2624
# weighted avg       0.86      0.84      0.84      2624
#
# Time span:616.28395
# ===>epoch:020===>
# #train_set:0, loss:0.28189, Train_acc:0.86172
# #train_set:1, loss:0.28204, Train_acc:0.87187
# #train_set:2, loss:0.28279, Train_acc:0.87148
# #train_set:3, loss:0.27204, Train_acc:0.87500
# avg loss:0.27969
# Test_acc:0.85404
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.89      0.83      0.86      1297
#            1       0.99      0.91      0.95       218
#            2       0.90      0.62      0.74       133
#            3       0.77      0.73      0.75       153
#            4       0.76      0.93      0.84       669
#            5       0.95      0.96      0.96       154
#
#     accuracy                           0.85      2624
#    macro avg       0.88      0.83      0.85      2624
# weighted avg       0.86      0.85      0.85      2624
#
# Time span:646.63730
# ===>epoch:021===>
# #train_set:0, loss:0.26252, Train_acc:0.87266
# #train_set:1, loss:0.28989, Train_acc:0.86641
# #train_set:2, loss:0.26302, Train_acc:0.86758
# #train_set:3, loss:0.25744, Train_acc:0.87422
# avg loss:0.26822
# Test_acc:0.85099
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.87      0.85      0.86      1297
#            1       1.00      0.87      0.93       218
#            2       0.86      0.61      0.71       133
#            3       0.84      0.61      0.71       153
#            4       0.77      0.92      0.84       669
#            5       0.94      0.96      0.95       154
#
#     accuracy                           0.85      2624
#    macro avg       0.88      0.80      0.83      2624
# weighted avg       0.86      0.85      0.85      2624
#
# Time span:676.53187
# ===>epoch:022===>
# #train_set:0, loss:0.26337, Train_acc:0.87539
# #train_set:1, loss:0.26527, Train_acc:0.87266
# #train_set:2, loss:0.26628, Train_acc:0.87656
# #train_set:3, loss:0.26513, Train_acc:0.87187
# avg loss:0.26501
# Test_acc:0.84413
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.88      0.82      0.85      1297
#            1       1.00      0.87      0.93       218
#            2       0.91      0.65      0.76       133
#            3       0.74      0.63      0.68       153
#            4       0.75      0.94      0.83       669
#            5       0.93      0.96      0.95       154
#
#     accuracy                           0.84      2624
#    macro avg       0.87      0.81      0.83      2624
# weighted avg       0.85      0.84      0.84      2624
#
# Time span:707.14458
# ===>epoch:023===>
# #train_set:0, loss:0.25664, Train_acc:0.87422
# #train_set:1, loss:0.29119, Train_acc:0.87383
# #train_set:2, loss:0.26598, Train_acc:0.87109
# #train_set:3, loss:0.26411, Train_acc:0.87734
# avg loss:0.26948
# Test_acc:0.85213
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.90      0.82      0.86      1297
#            1       1.00      0.87      0.93       218
#            2       0.92      0.62      0.74       133
#            3       0.74      0.72      0.73       153
#            4       0.74      0.97      0.84       669
#            5       1.00      0.92      0.96       154
#
#     accuracy                           0.85      2624
#    macro avg       0.88      0.82      0.84      2624
# weighted avg       0.87      0.85      0.85      2624
#
# Time span:737.99864
# ===>epoch:024===>
# #train_set:0, loss:0.25541, Train_acc:0.88398
# #train_set:1, loss:0.28858, Train_acc:0.86953
# #train_set:2, loss:0.26248, Train_acc:0.87773
# #train_set:3, loss:0.24973, Train_acc:0.88359
# avg loss:0.26405
# Test_acc:0.85480
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.87      0.85      0.86      1297
#            1       1.00      0.89      0.94       218
#            2       0.89      0.64      0.75       133
#            3       0.85      0.65      0.74       153
#            4       0.77      0.92      0.84       669
#            5       0.95      0.99      0.97       154
#
#     accuracy                           0.85      2624
#    macro avg       0.89      0.82      0.85      2624
# weighted avg       0.86      0.85      0.85      2624
#
# Time span:768.22836
# ===>epoch:025===>
# #train_set:0, loss:0.24325, Train_acc:0.87227
# #train_set:1, loss:0.27357, Train_acc:0.87461
# #train_set:2, loss:0.25582, Train_acc:0.87187
# #train_set:3, loss:0.26967, Train_acc:0.87461
# avg loss:0.26058
# Test_acc:0.85137
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.87      0.85      0.86      1297
#            1       1.00      0.85      0.92       218
#            2       0.95      0.59      0.73       133
#            3       0.81      0.74      0.77       153
#            4       0.77      0.92      0.84       669
#            5       0.94      0.95      0.95       154
#
#     accuracy                           0.85      2624
#    macro avg       0.89      0.82      0.84      2624
# weighted avg       0.86      0.85      0.85      2624
#
# Time span:797.68720
# ===>epoch:026===>
# #train_set:0, loss:0.23848, Train_acc:0.87461
# #train_set:1, loss:0.26436, Train_acc:0.86836
# #train_set:2, loss:0.26112, Train_acc:0.87813
# #train_set:3, loss:0.24937, Train_acc:0.88008
# avg loss:0.25333
# Test_acc:0.85556
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.88      0.84      0.86      1297
#            1       1.00      0.87      0.93       218
#            2       0.89      0.71      0.79       133
#            3       0.80      0.68      0.73       153
#            4       0.77      0.92      0.84       669
#            5       0.96      0.96      0.96       154
#
#     accuracy                           0.86      2624
#    macro avg       0.88      0.83      0.85      2624
# weighted avg       0.86      0.86      0.86      2624
#
# Time span:827.85991
# ===>epoch:027===>
# #train_set:0, loss:0.23564, Train_acc:0.88281
# #train_set:1, loss:0.27149, Train_acc:0.87383
# #train_set:2, loss:0.24938, Train_acc:0.86680
# #train_set:3, loss:0.25093, Train_acc:0.88203
# avg loss:0.25186
# Test_acc:0.85442
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.88      0.84      0.86      1297
#            1       0.97      0.90      0.93       218
#            2       0.90      0.68      0.78       133
#            3       0.80      0.69      0.74       153
#            4       0.76      0.92      0.83       669
#            5       0.96      0.97      0.96       154
#
#     accuracy                           0.85      2624
#    macro avg       0.88      0.83      0.85      2624
# weighted avg       0.86      0.85      0.85      2624
#
# Time span:857.81647
# ===>epoch:028===>
# #train_set:0, loss:0.23302, Train_acc:0.88203
# #train_set:1, loss:0.24609, Train_acc:0.87344
# #train_set:2, loss:0.25722, Train_acc:0.86836
# #train_set:3, loss:0.24513, Train_acc:0.87813
# avg loss:0.24536
# Test_acc:0.85518
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.87      0.86      0.86      1297
#            1       0.95      0.91      0.93       218
#            2       0.97      0.65      0.77       133
#            3       0.95      0.61      0.74       153
#            4       0.77      0.92      0.84       669
#            5       0.96      0.92      0.94       154
#
#     accuracy                           0.86      2624
#    macro avg       0.91      0.81      0.85      2624
# weighted avg       0.86      0.86      0.85      2624
#
# Time span:887.65933
# ===>epoch:029===>
# #train_set:0, loss:0.28343, Train_acc:0.88125
# #train_set:1, loss:0.26576, Train_acc:0.87539
# #train_set:2, loss:0.24157, Train_acc:0.87148
# #train_set:3, loss:0.25104, Train_acc:0.87695
# avg loss:0.26045
# Test_acc:0.84718
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.88      0.84      0.86      1297
#            1       0.93      0.95      0.94       218
#            2       0.83      0.71      0.76       133
#            3       0.74      0.66      0.70       153
#            4       0.78      0.88      0.83       669
#            5       0.97      0.95      0.96       154
#
#     accuracy                           0.85      2624
#    macro avg       0.85      0.83      0.84      2624
# weighted avg       0.85      0.85      0.85      2624
#
# Time span:918.60481
# ===>epoch:030===>
# #train_set:0, loss:0.33918, Train_acc:0.87617
# #train_set:1, loss:0.25639, Train_acc:0.87891
# #train_set:2, loss:0.25713, Train_acc:0.87187
# #train_set:3, loss:0.24368, Train_acc:0.88867
# avg loss:0.27409
# Test_acc:0.85747
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.86      0.88      0.87      1297
#            1       0.96      0.89      0.93       218
#            2       0.87      0.65      0.74       133
#            3       0.93      0.61      0.74       153
#            4       0.79      0.88      0.84       669
#            5       0.96      0.95      0.95       154
#
#     accuracy                           0.86      2624
#    macro avg       0.90      0.81      0.84      2624
# weighted avg       0.86      0.86      0.86      2624
#
# Time span:948.20640
# ===>epoch:031===>
# #train_set:0, loss:0.23487, Train_acc:0.88164
# #train_set:1, loss:0.25053, Train_acc:0.87578
# #train_set:2, loss:0.24462, Train_acc:0.86719
# #train_set:3, loss:0.26871, Train_acc:0.88086
# avg loss:0.24968
# Test_acc:0.85099
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.92      0.80      0.85      1297
#            1       0.94      0.93      0.93       218
#            2       0.93      0.64      0.76       133
#            3       0.80      0.67      0.73       153
#            4       0.73      0.98      0.84       669
#            5       0.93      0.97      0.95       154
#
#     accuracy                           0.85      2624
#    macro avg       0.88      0.83      0.84      2624
# weighted avg       0.87      0.85      0.85      2624
#
# Time span:978.96101
# ===>epoch:032===>
# #train_set:0, loss:0.25147, Train_acc:0.85391
# #train_set:1, loss:0.26332, Train_acc:0.87461
# #train_set:2, loss:0.23657, Train_acc:0.87148
# #train_set:3, loss:0.24282, Train_acc:0.88633
# avg loss:0.24855
# Test_acc:0.85861
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.88      0.84      0.86      1297
#            1       0.95      0.91      0.93       218
#            2       0.93      0.69      0.79       133
#            3       0.89      0.70      0.78       153
#            4       0.76      0.92      0.84       669
#            5       0.99      0.95      0.97       154
#
#     accuracy                           0.86      2624
#    macro avg       0.90      0.84      0.86      2624
# weighted avg       0.87      0.86      0.86      2624
#
# Time span:1009.38943
# ===>epoch:033===>
# #train_set:0, loss:0.24964, Train_acc:0.88438
# #train_set:1, loss:0.25500, Train_acc:0.87227
# #train_set:2, loss:0.24076, Train_acc:0.86758
# #train_set:3, loss:0.24141, Train_acc:0.88008
# avg loss:0.24670
# Test_acc:0.85252
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.88      0.84      0.86      1297
#            1       0.99      0.89      0.93       218
#            2       0.96      0.60      0.74       133
#            3       0.77      0.73      0.75       153
#            4       0.77      0.91      0.84       669
#            5       0.91      0.97      0.94       154
#
#     accuracy                           0.85      2624
#    macro avg       0.88      0.82      0.84      2624
# weighted avg       0.86      0.85      0.85      2624
#
# Time span:1041.41519
# ===>epoch:034===>
# #train_set:0, loss:0.23785, Train_acc:0.87852
# #train_set:1, loss:0.25017, Train_acc:0.87539
# #train_set:2, loss:0.23170, Train_acc:0.87773
# #train_set:3, loss:0.24345, Train_acc:0.88398
# avg loss:0.24079
# Test_acc:0.85671
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.87      0.86      0.86      1297
#            1       1.00      0.87      0.93       218
#            2       0.92      0.62      0.74       133
#            3       0.89      0.65      0.75       153
#            4       0.77      0.92      0.84       669
#            5       0.96      0.95      0.95       154
#
#     accuracy                           0.86      2624
#    macro avg       0.90      0.81      0.85      2624
# weighted avg       0.86      0.86      0.86      2624
#
# Time span:1072.11871
# ===>epoch:035===>
# #train_set:0, loss:0.23839, Train_acc:0.88633
# #train_set:1, loss:0.24672, Train_acc:0.87500
# #train_set:2, loss:0.24372, Train_acc:0.88359
# #train_set:3, loss:0.23666, Train_acc:0.88555
# avg loss:0.24137
# Test_acc:0.85938
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.88      0.85      0.86      1297
#            1       1.00      0.87      0.93       218
#            2       0.89      0.71      0.79       133
#            3       0.88      0.65      0.75       153
#            4       0.77      0.92      0.84       669
#            5       0.96      0.97      0.96       154
#
#     accuracy                           0.86      2624
#    macro avg       0.90      0.83      0.86      2624
# weighted avg       0.87      0.86      0.86      2624
#
# Time span:1102.54019
# ===>epoch:036===>
# #train_set:0, loss:0.23048, Train_acc:0.88555
# #train_set:1, loss:0.23429, Train_acc:0.88125
# #train_set:2, loss:0.24236, Train_acc:0.87773
# #train_set:3, loss:0.23167, Train_acc:0.88359
# avg loss:0.23470
# Test_acc:0.85404
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.89      0.82      0.86      1297
#            1       0.91      0.94      0.93       218
#            2       0.85      0.72      0.78       133
#            3       0.82      0.63      0.72       153
#            4       0.77      0.93      0.84       669
#            5       0.94      0.99      0.97       154
#
#     accuracy                           0.85      2624
#    macro avg       0.87      0.84      0.85      2624
# weighted avg       0.86      0.85      0.85      2624
#
# Time span:1132.94690
# ===>epoch:037===>
# #train_set:0, loss:0.23389, Train_acc:0.86406
# #train_set:1, loss:0.24908, Train_acc:0.86133
# #train_set:2, loss:0.25383, Train_acc:0.88359
# #train_set:3, loss:0.23136, Train_acc:0.87813
# avg loss:0.24204
# Test_acc:0.85861
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.88      0.85      0.86      1297
#            1       0.92      0.95      0.94       218
#            2       0.95      0.62      0.75       133
#            3       0.92      0.64      0.75       153
#            4       0.77      0.92      0.84       669
#            5       0.98      0.97      0.97       154
#
#     accuracy                           0.86      2624
#    macro avg       0.90      0.83      0.85      2624
# weighted avg       0.87      0.86      0.86      2624
#
# Time span:1162.78594
# ===>epoch:038===>
# #train_set:0, loss:0.22630, Train_acc:0.88438
# #train_set:1, loss:0.24070, Train_acc:0.87773
# #train_set:2, loss:0.25598, Train_acc:0.87227
# #train_set:3, loss:0.24825, Train_acc:0.88125
# avg loss:0.24281
# Test_acc:0.85518
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.88      0.85      0.86      1297
#            1       0.96      0.92      0.94       218
#            2       0.91      0.65      0.76       133
#            3       0.96      0.59      0.73       153
#            4       0.75      0.93      0.83       669
#            5       0.96      0.95      0.95       154
#
#     accuracy                           0.86      2624
#    macro avg       0.90      0.82      0.85      2624
# weighted avg       0.87      0.86      0.85      2624
#
# Time span:1192.52447
# ===>epoch:039===>
# #train_set:0, loss:0.22687, Train_acc:0.88633
# #train_set:1, loss:0.22655, Train_acc:0.88164
# #train_set:2, loss:0.25209, Train_acc:0.87227
# #train_set:3, loss:0.23852, Train_acc:0.89062
# avg loss:0.23601
# Test_acc:0.86433
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.86      0.88      0.87      1297
#            1       1.00      0.87      0.93       218
#            2       0.95      0.67      0.78       133
#            3       0.86      0.70      0.77       153
#            4       0.80      0.89      0.84       669
#            5       0.96      0.97      0.96       154
#
#     accuracy                           0.86      2624
#    macro avg       0.90      0.83      0.86      2624
# weighted avg       0.87      0.86      0.86      2624
#
# Time span:1222.10448
# ===>epoch:040===>
# #train_set:0, loss:0.23400, Train_acc:0.87656
# #train_set:1, loss:0.24002, Train_acc:0.88203
# #train_set:2, loss:0.22268, Train_acc:0.87187
# #train_set:3, loss:0.22788, Train_acc:0.87852
# avg loss:0.23115
# Test_acc:0.85366
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.87      0.85      0.86      1297
#            1       0.99      0.89      0.93       218
#            2       0.96      0.61      0.75       133
#            3       0.86      0.67      0.75       153
#            4       0.76      0.92      0.83       669
#            5       0.96      0.97      0.96       154
#
#     accuracy                           0.85      2624
#    macro avg       0.90      0.82      0.85      2624
# weighted avg       0.86      0.85      0.85      2624
#
# Time span:1253.23229
# ===>epoch:041===>
# #train_set:0, loss:0.22719, Train_acc:0.88008
# #train_set:1, loss:0.23567, Train_acc:0.88203
# #train_set:2, loss:0.23138, Train_acc:0.87187
# #train_set:3, loss:0.23392, Train_acc:0.87656
# avg loss:0.23204
# Test_acc:0.84947
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.88      0.85      0.86      1297
#            1       0.95      0.94      0.94       218
#            2       0.76      0.71      0.73       133
#            3       0.93      0.46      0.62       153
#            4       0.76      0.92      0.83       669
#            5       0.97      0.92      0.94       154
#
#     accuracy                           0.85      2624
#    macro avg       0.88      0.80      0.82      2624
# weighted avg       0.86      0.85      0.85      2624
#
# Time span:1284.23291
# ===>epoch:042===>
# #train_set:0, loss:0.25134, Train_acc:0.87187
# #train_set:1, loss:0.25049, Train_acc:0.87031
# #train_set:2, loss:0.24116, Train_acc:0.87187
# #train_set:3, loss:0.23376, Train_acc:0.87383
# avg loss:0.24419
# Test_acc:0.87043
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.82      0.97      0.89      1297
#            1       0.95      0.92      0.93       218
#            2       0.90      0.67      0.77       133
#            3       0.85      0.60      0.70       153
#            4       0.95      0.75      0.84       669
#            5       0.96      0.95      0.96       154
#
#     accuracy                           0.87      2624
#    macro avg       0.91      0.81      0.85      2624
# weighted avg       0.88      0.87      0.87      2624
#
# Time span:1314.66751
# ===>epoch:043===>
# #train_set:0, loss:0.23230, Train_acc:0.88242
# #train_set:1, loss:0.24519, Train_acc:0.87656
# #train_set:2, loss:0.23507, Train_acc:0.88047
# #train_set:3, loss:0.23008, Train_acc:0.88203
# avg loss:0.23566
# Test_acc:0.85899
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.89      0.84      0.86      1297
#            1       0.91      0.98      0.94       218
#            2       0.95      0.66      0.78       133
#            3       0.92      0.63      0.75       153
#            4       0.76      0.92      0.83       669
#            5       0.94      0.99      0.97       154
#
#     accuracy                           0.86      2624
#    macro avg       0.89      0.84      0.86      2624
# weighted avg       0.87      0.86      0.86      2624
#
# Time span:1344.61459
# ===>epoch:044===>
# #train_set:0, loss:0.22601, Train_acc:0.88164
# #train_set:1, loss:0.22820, Train_acc:0.88242
# #train_set:2, loss:0.26046, Train_acc:0.87227
# #train_set:3, loss:0.23632, Train_acc:0.88359
# avg loss:0.23775
# Test_acc:0.85328
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.87      0.85      0.86      1297
#            1       0.98      0.89      0.93       218
#            2       0.93      0.66      0.77       133
#            3       0.86      0.62      0.72       153
#            4       0.76      0.92      0.84       669
#            5       0.96      0.95      0.96       154
#
#     accuracy                           0.85      2624
#    macro avg       0.89      0.82      0.85      2624
# weighted avg       0.86      0.85      0.85      2624
#
# Time span:1374.98254
# ===>epoch:045===>
# #train_set:0, loss:0.22859, Train_acc:0.88477
# #train_set:1, loss:0.23417, Train_acc:0.87227
# #train_set:2, loss:0.23211, Train_acc:0.88398
# #train_set:3, loss:0.22429, Train_acc:0.88594
# avg loss:0.22979
# Test_acc:0.85899
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.89      0.83      0.86      1297
#            1       0.95      0.90      0.93       218
#            2       0.93      0.67      0.78       133
#            3       0.84      0.73      0.78       153
#            4       0.76      0.94      0.84       669
#            5       0.96      0.99      0.97       154
#
#     accuracy                           0.86      2624
#    macro avg       0.89      0.84      0.86      2624
# weighted avg       0.87      0.86      0.86      2624
#
# Time span:1405.60540
# ===>epoch:046===>
# #train_set:0, loss:0.21681, Train_acc:0.88477
# #train_set:1, loss:0.22550, Train_acc:0.87461
# #train_set:2, loss:0.22999, Train_acc:0.88203
# #train_set:3, loss:0.22395, Train_acc:0.87852
# avg loss:0.22406
# Test_acc:0.87652
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.82      0.98      0.89      1297
#            1       0.97      0.89      0.93       218
#            2       0.95      0.68      0.79       133
#            3       0.90      0.69      0.78       153
#            4       0.96      0.74      0.83       669
#            5       0.96      0.99      0.98       154
#
#     accuracy                           0.88      2624
#    macro avg       0.93      0.83      0.87      2624
# weighted avg       0.89      0.88      0.87      2624
#
# Time span:1436.19034
# ===>epoch:047===>
# #train_set:0, loss:0.23095, Train_acc:0.88281
# #train_set:1, loss:0.23504, Train_acc:0.87773
# #train_set:2, loss:0.23794, Train_acc:0.88398
# #train_set:3, loss:0.22001, Train_acc:0.88477
# avg loss:0.23099
# Test_acc:0.85861
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86      1297
#            1       1.00      0.87      0.93       218
#            2       0.95      0.63      0.76       133
#            3       0.95      0.63      0.76       153
#            4       0.77      0.92      0.84       669
#            5       0.96      0.96      0.96       154
#
#     accuracy                           0.86      2624
#    macro avg       0.92      0.81      0.85      2624
# weighted avg       0.87      0.86      0.86      2624
#
# Time span:1466.33764
# ===>epoch:048===>
# #train_set:0, loss:0.22332, Train_acc:0.88359
# #train_set:1, loss:0.22935, Train_acc:0.88203
# #train_set:2, loss:0.22878, Train_acc:0.87383
# #train_set:3, loss:0.22198, Train_acc:0.87617
# avg loss:0.22586
# Test_acc:0.87919
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.82      0.98      0.89      1297
#            1       1.00      0.87      0.93       218
#            2       0.89      0.75      0.82       133
#            3       0.94      0.66      0.78       153
#            4       0.97      0.73      0.84       669
#            5       0.95      0.99      0.97       154
#
#     accuracy                           0.88      2624
#    macro avg       0.93      0.83      0.87      2624
# weighted avg       0.89      0.88      0.88      2624
#
# Time span:1496.26454
# ===>epoch:049===>
# #train_set:0, loss:0.21999, Train_acc:0.88945
# #train_set:1, loss:0.23788, Train_acc:0.88125
# #train_set:2, loss:0.22747, Train_acc:0.87773
# #train_set:3, loss:0.24048, Train_acc:0.88164
# avg loss:0.23146
# Test_acc:0.85556
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.87      0.85      0.86      1297
#            1       1.00      0.87      0.93       218
#            2       0.93      0.65      0.77       133
#            3       0.93      0.65      0.76       153
#            4       0.76      0.92      0.83       669
#            5       0.95      0.98      0.96       154
#
#     accuracy                           0.86      2624
#    macro avg       0.91      0.82      0.85      2624
# weighted avg       0.86      0.86      0.86      2624
#
# Time span:1527.21150
# ===>epoch:050===>
# #train_set:0, loss:0.21874, Train_acc:0.88516
# #train_set:1, loss:0.22914, Train_acc:0.87461
# #train_set:2, loss:0.24929, Train_acc:0.88008
# #train_set:3, loss:0.22382, Train_acc:0.88672
# avg loss:0.23025
# Test_acc:0.85594
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.89      0.83      0.86      1297
#            1       0.91      0.95      0.93       218
#            2       0.95      0.66      0.78       133
#            3       0.78      0.76      0.77       153
#            4       0.78      0.91      0.84       669
#            5       0.96      0.95      0.96       154
#
#     accuracy                           0.86      2624
#    macro avg       0.88      0.84      0.86      2624
# weighted avg       0.86      0.86      0.86      2624
#
# Time span:1556.46914
# ===>epoch:051===>
# #train_set:0, loss:0.21739, Train_acc:0.88672
# #train_set:1, loss:0.23362, Train_acc:0.87930
# #train_set:2, loss:0.23590, Train_acc:0.87187
# #train_set:3, loss:0.23259, Train_acc:0.88516
# avg loss:0.22987
# Test_acc:0.85518
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.87      0.85      0.86      1297
#            1       1.00      0.87      0.93       218
#            2       0.86      0.67      0.75       133
#            3       0.88      0.69      0.77       153
#            4       0.77      0.91      0.83       669
#            5       0.96      0.97      0.96       154
#
#     accuracy                           0.86      2624
#    macro avg       0.89      0.82      0.85      2624
# weighted avg       0.86      0.86      0.85      2624
#
# Time span:1585.49159
# ===>epoch:052===>
# #train_set:0, loss:0.22625, Train_acc:0.87969
# #train_set:1, loss:0.21871, Train_acc:0.88398
# #train_set:2, loss:0.22086, Train_acc:0.88672
# #train_set:3, loss:0.23383, Train_acc:0.88008
# avg loss:0.22491
# Test_acc:0.85633
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.82      0.93      0.87      1297
#            1       1.00      0.87      0.93       218
#            2       0.89      0.58      0.70       133
#            3       0.96      0.52      0.68       153
#            4       0.84      0.83      0.83       669
#            5       1.00      0.93      0.96       154
#
#     accuracy                           0.86      2624
#    macro avg       0.92      0.78      0.83      2624
# weighted avg       0.86      0.86      0.85      2624
#
# Time span:1614.46574
# ===>epoch:053===>
# #train_set:0, loss:0.23015, Train_acc:0.88164
# #train_set:1, loss:0.26015, Train_acc:0.87578
# #train_set:2, loss:0.22818, Train_acc:0.88242
# #train_set:3, loss:0.24643, Train_acc:0.87461
# avg loss:0.24123
# Test_acc:0.85328
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.89      0.83      0.86      1297
#            1       0.94      0.91      0.93       218
#            2       0.78      0.69      0.73       133
#            3       0.77      0.71      0.74       153
#            4       0.78      0.91      0.84       669
#            5       0.95      0.98      0.96       154
#
#     accuracy                           0.85      2624
#    macro avg       0.85      0.84      0.84      2624
# weighted avg       0.86      0.85      0.85      2624
#
# Time span:1643.32611
# ===>epoch:054===>
# #train_set:0, loss:0.25094, Train_acc:0.89062
# #train_set:1, loss:0.27034, Train_acc:0.88047
# #train_set:2, loss:0.22525, Train_acc:0.87891
# #train_set:3, loss:0.22778, Train_acc:0.88711
# avg loss:0.24358
# Test_acc:0.85976
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.88      0.85      0.86      1297
#            1       0.96      0.89      0.92       218
#            2       0.88      0.70      0.78       133
#            3       0.88      0.67      0.76       153
#            4       0.78      0.92      0.84       669
#            5       0.96      0.99      0.97       154
#
#     accuracy                           0.86      2624
#    macro avg       0.89      0.84      0.86      2624
# weighted avg       0.86      0.86      0.86      2624
#
# Time span:1672.62815
# ===>epoch:055===>
# #train_set:0, loss:0.22419, Train_acc:0.88828
# #train_set:1, loss:0.22949, Train_acc:0.88203
# #train_set:2, loss:0.22804, Train_acc:0.88438
# #train_set:3, loss:0.21229, Train_acc:0.88945
# avg loss:0.22350
# Test_acc:0.85976
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.87      0.86      0.86      1297
#            1       1.00      0.87      0.93       218
#            2       0.91      0.65      0.76       133
#            3       0.94      0.65      0.77       153
#            4       0.77      0.92      0.84       669
#            5       0.97      0.97      0.97       154
#
#     accuracy                           0.86      2624
#    macro avg       0.91      0.82      0.86      2624
# weighted avg       0.87      0.86      0.86      2624
#
# Time span:1704.06039
# ===>epoch:056===>
# #train_set:0, loss:0.22214, Train_acc:0.88164
# #train_set:1, loss:0.22210, Train_acc:0.88242
# #train_set:2, loss:0.21876, Train_acc:0.88477
# #train_set:3, loss:0.22027, Train_acc:0.88672
# avg loss:0.22082
# Test_acc:0.86090
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.87      0.86      0.87      1297
#            1       1.00      0.87      0.93       218
#            2       1.00      0.62      0.76       133
#            3       0.93      0.67      0.78       153
#            4       0.77      0.92      0.84       669
#            5       0.96      0.97      0.97       154
#
#     accuracy                           0.86      2624
#    macro avg       0.92      0.82      0.86      2624
# weighted avg       0.87      0.86      0.86      2624
#
# Time span:1733.75775
# ===>epoch:057===>
# #train_set:0, loss:0.21563, Train_acc:0.88203
# #train_set:1, loss:0.22487, Train_acc:0.88203
# #train_set:2, loss:0.22439, Train_acc:0.88594
# #train_set:3, loss:0.21740, Train_acc:0.88828
# avg loss:0.22057
# Test_acc:0.85861
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.87      0.85      0.86      1297
# ...
#            2       0.88      0.66      0.76       133
#            3       0.88      0.70      0.78       153
#            4       0.78      0.91      0.84       669
#            5       0.99      0.96      0.97       154
#
#     accuracy                           0.86      2624
#    macro avg       0.90      0.83      0.86      2624
# weighted avg       0.87      0.86      0.86      2624
#
# Time span:1853.59784
# ===>epoch:061===>
# #train_set:0, loss:0.21263, Train_acc:0.88398
# #train_set:1, loss:0.22022, Train_acc:0.88477
# #train_set:2, loss:0.22128, Train_acc:0.88711
# #train_set:3, loss:0.21630, Train_acc:0.88555
# avg loss:0.21761
# Test_acc:0.85976
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.89      0.83      0.86      1297
#            1       0.94      0.93      0.94       218
#            2       0.88      0.73      0.80       133
#            3       0.82      0.71      0.76       153
#            4       0.77      0.92      0.84       669
#            5       0.96      0.98      0.97       154
#
#     accuracy                           0.86      2624
#    macro avg       0.88      0.85      0.86      2624
# weighted avg       0.86      0.86      0.86      2624
#
# Time span:1882.34485
# ===>epoch:062===>
# #train_set:0, loss:0.21096, Train_acc:0.88672
# #train_set:1, loss:0.24006, Train_acc:0.88555
# #train_set:2, loss:0.22333, Train_acc:0.88398
# #train_set:3, loss:0.22008, Train_acc:0.87969
# avg loss:0.22361
# Test_acc:0.86014
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.89      0.84      0.86      1297
#            1       0.92      0.96      0.94       218
#            2       0.95      0.67      0.78       133
#            3       0.90      0.68      0.77       153
#            4       0.77      0.92      0.84       669
#            5       0.97      0.98      0.97       154
#
#     accuracy                           0.86      2624
#    macro avg       0.90      0.84      0.86      2624
# weighted avg       0.87      0.86      0.86      2624
#
# Time span:1912.23866
# ===>epoch:063===>
# #train_set:0, loss:0.21473, Train_acc:0.88750
# #train_set:1, loss:0.21840, Train_acc:0.87891
# #train_set:2, loss:0.22478, Train_acc:0.88867
# #train_set:3, loss:0.21289, Train_acc:0.89102
# avg loss:0.21770
# Test_acc:0.85518
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.88      0.84      0.86      1297
#            1       0.94      0.91      0.93       218
#            2       0.85      0.68      0.76       133
#            3       0.86      0.69      0.77       153
#            4       0.78      0.90      0.83       669
#            5       0.95      0.98      0.96       154
#
#     accuracy                           0.86      2624
#    macro avg       0.88      0.84      0.85      2624
# weighted avg       0.86      0.86      0.85      2624
#
# Time span:1942.92077
# ===>epoch:064===>
# #train_set:0, loss:0.23053, Train_acc:0.88203
# #train_set:1, loss:0.30529, Train_acc:0.87461
# #train_set:2, loss:0.21754, Train_acc:0.88320
# #train_set:3, loss:0.22136, Train_acc:0.87344
# avg loss:0.24368
# Test_acc:0.84908
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.85      0.87      0.86      1297
#            1       0.99      0.87      0.93       218
#            2       1.00      0.61      0.76       133
#            3       0.96      0.49      0.65       153
#            4       0.77      0.92      0.84       669
#            5       0.97      0.95      0.96       154
#
#     accuracy                           0.85      2624
#    macro avg       0.92      0.78      0.83      2624
# weighted avg       0.86      0.85      0.85      2624
#
# Time span:1973.38550
# ===>epoch:065===>
# #train_set:0, loss:0.22304, Train_acc:0.88320
# #train_set:1, loss:0.22585, Train_acc:0.88359
# #train_set:2, loss:0.22152, Train_acc:0.88398
# #train_set:3, loss:0.21038, Train_acc:0.89219
# avg loss:0.22020
# Test_acc:0.86090
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.88      0.85      0.86      1297
#            1       0.96      0.91      0.94       218
#            2       0.90      0.69      0.78       133
#            3       0.92      0.69      0.79       153
#            4       0.78      0.91      0.84       669
#            5       0.96      0.95      0.96       154
#
#     accuracy                           0.86      2624
#    macro avg       0.90      0.83      0.86      2624
# weighted avg       0.87      0.86      0.86      2624
#
# Time span:2003.83544
# ===>epoch:066===>
# #train_set:0, loss:0.20458, Train_acc:0.88711
# #train_set:1, loss:0.21597, Train_acc:0.88555
# #train_set:2, loss:0.21520, Train_acc:0.88594
# #train_set:3, loss:0.21293, Train_acc:0.88945
# avg loss:0.21217
# Test_acc:0.85976
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.88      0.85      0.86      1297
#            1       0.94      0.93      0.94       218
#            2       0.89      0.68      0.77       133
#            3       0.90      0.69      0.78       153
#            4       0.78      0.91      0.84       669
#            5       0.96      0.96      0.96       154
#
#     accuracy                           0.86      2624
#    macro avg       0.89      0.84      0.86      2624
# weighted avg       0.86      0.86      0.86      2624
#
# Time span:2033.70809
# ===>epoch:067===>
# #train_set:0, loss:0.21901, Train_acc:0.89180
# #train_set:1, loss:0.22093, Train_acc:0.88672
# #train_set:2, loss:0.22977, Train_acc:0.87852
# #train_set:3, loss:0.22812, Train_acc:0.88945
# avg loss:0.22446
# Test_acc:0.85480
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.87      0.85      0.86      1297
#            1       0.94      0.92      0.93       218
#            2       0.97      0.64      0.77       133
#            3       0.86      0.66      0.75       153
#            4       0.77      0.91      0.84       669
#            5       0.96      0.95      0.96       154
#
#     accuracy                           0.85      2624
#    macro avg       0.89      0.82      0.85      2624
# weighted avg       0.86      0.85      0.85      2624
#
# Time span:2064.27094
# ===>epoch:068===>
# #train_set:0, loss:0.20872, Train_acc:0.88477
# #train_set:1, loss:0.21479, Train_acc:0.88516
# #train_set:2, loss:0.21724, Train_acc:0.88555
# #train_set:3, loss:0.21363, Train_acc:0.89219
# avg loss:0.21360
# Test_acc:0.86166
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.88      0.86      0.87      1297
#            1       0.99      0.89      0.94       218
#            2       0.99      0.63      0.77       133
#            3       0.88      0.69      0.78       153
#            4       0.77      0.92      0.84       669
#            5       0.97      0.97      0.97       154
#
#     accuracy                           0.86      2624
#    macro avg       0.91      0.83      0.86      2624
# weighted avg       0.87      0.86      0.86      2624
#
# Time span:2093.95445
# ===>epoch:069===>
# #train_set:0, loss:0.21046, Train_acc:0.88828
# #train_set:1, loss:0.21595, Train_acc:0.87969
# #train_set:2, loss:0.22014, Train_acc:0.88867
# #train_set:3, loss:0.21726, Train_acc:0.89180
# avg loss:0.21595
# Test_acc:0.86357
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87      1297
#            1       0.99      0.89      0.93       218
#            2       0.97      0.65      0.77       133
#            3       0.80      0.73      0.76       153
#            4       0.79      0.90      0.84       669
#            5       1.00      0.95      0.98       154
#
#     accuracy                           0.86      2624
#    macro avg       0.90      0.83      0.86      2624
# weighted avg       0.87      0.86      0.86      2624
#
# Time span:2124.29027
# ===>epoch:070===>
# #train_set:0, loss:0.20531, Train_acc:0.88555
# #train_set:1, loss:0.20734, Train_acc:0.88594
# #train_set:2, loss:0.21168, Train_acc:0.88750
# #train_set:3, loss:0.21600, Train_acc:0.88125
# avg loss:0.21008
# Test_acc:0.85709
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.83      0.91      0.87      1297
#            1       1.00      0.87      0.93       218
#            2       0.94      0.61      0.74       133
#            3       0.91      0.61      0.73       153
#            4       0.82      0.83      0.83       669
#            5       0.95      0.99      0.97       154
#
#     accuracy                           0.86      2624
#    macro avg       0.91      0.80      0.84      2624
# weighted avg       0.86      0.86      0.85      2624
#
# Time span:2155.07085
# ===>epoch:071===>
# #train_set:0, loss:0.32762, Train_acc:0.87422
# #train_set:1, loss:0.23814, Train_acc:0.87344
# #train_set:2, loss:0.22616, Train_acc:0.87773
# #train_set:3, loss:0.21583, Train_acc:0.89258
# avg loss:0.25194
# Test_acc:0.85938
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.86      0.87      0.87      1297
#            1       1.00      0.87      0.93       218
#            2       0.91      0.63      0.75       133
#            3       0.93      0.65      0.76       153
#            4       0.77      0.91      0.84       669
#            5       1.00      0.95      0.98       154
#
#     accuracy                           0.86      2624
#    macro avg       0.91      0.81      0.85      2624
# weighted avg       0.87      0.86      0.86      2624
#
# Time span:2185.43050
# ===>epoch:072===>
# #train_set:0, loss:0.21247, Train_acc:0.88516
# #train_set:1, loss:0.21565, Train_acc:0.88359
# #train_set:2, loss:0.22464, Train_acc:0.88047
# #train_set:3, loss:0.22477, Train_acc:0.88750
# avg loss:0.21938
# Test_acc:0.85556
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.88      0.84      0.86      1297
#            1       0.98      0.88      0.93       218
#            2       0.89      0.68      0.77       133
#            3       0.75      0.79      0.77       153
#            4       0.78      0.89      0.83       669
#            5       0.95      1.00      0.97       154
#
#     accuracy                           0.86      2624
#    macro avg       0.87      0.85      0.86      2624
# weighted avg       0.86      0.86      0.86      2624
#
# Time span:2216.47545
# ===>epoch:073===>
# #train_set:0, loss:0.21330, Train_acc:0.87734
# #train_set:1, loss:0.21781, Train_acc:0.88398
# #train_set:2, loss:0.21086, Train_acc:0.88320
# #train_set:3, loss:0.20893, Train_acc:0.89219
# avg loss:0.21273
# Test_acc:0.85938
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.87      0.86      0.87      1297
#            1       0.98      0.88      0.93       218
#            2       0.98      0.61      0.75       133
#            3       0.87      0.69      0.77       153
#            4       0.77      0.91      0.84       669
#            5       0.97      0.97      0.97       154
#
#     accuracy                           0.86      2624
#    macro avg       0.91      0.82      0.85      2624
# weighted avg       0.87      0.86      0.86      2624
#
# Time span:2247.85469
# ===>epoch:074===>
# #train_set:0, loss:0.21089, Train_acc:0.88750
# #train_set:1, loss:0.21165, Train_acc:0.88789
# #train_set:2, loss:0.21351, Train_acc:0.88906
# #train_set:3, loss:0.21743, Train_acc:0.88867
# avg loss:0.21337
# Test_acc:0.85938
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86      1297
#            1       1.00      0.87      0.93       218
#            2       0.96      0.64      0.77       133
#            3       0.93      0.65      0.76       153
#            4       0.78      0.91      0.84       669
#            5       0.96      0.99      0.97       154
#
#     accuracy                           0.86      2624
#    macro avg       0.92      0.82      0.86      2624
# weighted avg       0.87      0.86      0.86      2624
#
# Time span:2278.26624
# ===>epoch:075===>
# #train_set:0, loss:0.23146, Train_acc:0.88594
# #train_set:1, loss:0.22716, Train_acc:0.88320
# #train_set:2, loss:0.21759, Train_acc:0.87969
# #train_set:3, loss:0.22115, Train_acc:0.88594
# avg loss:0.22434
# Test_acc:0.86700
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.85      0.91      0.88      1297
#            1       0.93      0.92      0.93       218
#            2       0.93      0.65      0.77       133
#            3       0.93      0.65      0.76       153
#            4       0.84      0.83      0.83       669
#            5       0.94      0.99      0.97       154
#
#     accuracy                           0.87      2624
#    macro avg       0.90      0.83      0.86      2624
# weighted avg       0.87      0.87      0.86      2624
#
# Time span:2309.32466
# ===>epoch:076===>
# #train_set:0, loss:0.23424, Train_acc:0.87305
# #train_set:1, loss:0.21995, Train_acc:0.88672
# #train_set:2, loss:0.21834, Train_acc:0.87813
# #train_set:3, loss:0.21498, Train_acc:0.88555
# avg loss:0.22188
# Test_acc:0.86319
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.88      0.86      0.87      1297
#            1       0.93      0.97      0.95       218
#            2       0.95      0.65      0.77       133
#            3       0.96      0.63      0.76       153
#            4       0.77      0.92      0.84       669
#            5       0.99      0.97      0.98       154
#
#     accuracy                           0.86      2624
#    macro avg       0.91      0.83      0.86      2624
# weighted avg       0.87      0.86      0.86      2624
#
# Time span:2340.27876
# ===>epoch:077===>
# #train_set:0, loss:0.20645, Train_acc:0.89297
# #train_set:1, loss:0.20809, Train_acc:0.87695
# #train_set:2, loss:0.21546, Train_acc:0.88633
# #train_set:3, loss:0.21944, Train_acc:0.89023
# avg loss:0.21236
# Test_acc:0.86433
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.88      0.86      0.87      1297
#            1       1.00      0.89      0.94       218
#            2       0.94      0.63      0.76       133
#            3       0.97      0.63      0.76       153
#            4       0.77      0.93      0.84       669
#            5       0.95      0.99      0.97       154
#
#     accuracy                           0.86      2624
#    macro avg       0.92      0.82      0.86      2624
# weighted avg       0.87      0.86      0.86      2624
#
# Time span:2369.60459
# ===>epoch:078===>
# #train_set:0, loss:0.23709, Train_acc:0.88672
# #train_set:1, loss:0.23668, Train_acc:0.88594
# #train_set:2, loss:0.21269, Train_acc:0.87734
# #train_set:3, loss:0.20811, Train_acc:0.88398
# avg loss:0.22364
# Test_acc:0.85594
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.89      0.84      0.86      1297
#            1       0.91      0.99      0.95       218
#            2       0.75      0.71      0.73       133
#            3       0.87      0.56      0.68       153
#            4       0.78      0.91      0.84       669
#            5       0.96      0.97      0.97       154
#
#     accuracy                           0.86      2624
#    macro avg       0.86      0.83      0.84      2624
# weighted avg       0.86      0.86      0.85      2624
#
# Time span:2399.93571
# ===>epoch:079===>
# #train_set:0, loss:0.21894, Train_acc:0.89023
# #train_set:1, loss:0.21750, Train_acc:0.88672
# #train_set:2, loss:0.21015, Train_acc:0.88516
# #train_set:3, loss:0.20488, Train_acc:0.88789
# avg loss:0.21287
# Test_acc:0.86395
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.89      0.86      0.87      1297
#            1       1.00      0.87      0.93       218
#            2       0.88      0.67      0.76       133
#            3       0.93      0.67      0.78       153
#            4       0.77      0.93      0.84       669
#            5       0.93      1.00      0.97       154
#
#     accuracy                           0.86      2624
#    macro avg       0.90      0.83      0.86      2624
# weighted avg       0.87      0.86      0.86      2624
#
# Time span:2432.01994
# Total time span:2432.01994

# %%
# show res
print("best acc:{:.5f}, at epoch:{:3d}".format(best_acc['acc'], best_acc['epoch']))
# Out:
# best acc:0.87919, at epoch: 48

# %%
x = np.arange(0, 320, 1)
plt.title("all_loss for each train_file")
plt.xlabel("iteration * #train_file")
plt.ylabel("train loss")
plt.plot(x, all_loss_list)

# %%
x = np.arange(0, 80, 1)
plt.title("avg_loss for each epoch")
plt.xlabel("iteration")
plt.ylabel("train loss")
plt.plot(x, avg_loss_list)

# %%
x = np.arange(0, 80, 1)
plt.title("acc for each epoch")
plt.xlabel("iteration")
plt.ylabel("test loss")
plt.plot(x, acc_list)

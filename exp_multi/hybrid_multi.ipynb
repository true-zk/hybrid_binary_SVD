# %% [markdown]
# ### Hybrid model for multiple detect
# - load dataset
# - train model

# %%
import os
import gc
import time
import random
import pickle
import math
import numpy as np
import torch
import torch.nn as nn
from torch.nn import Linear
import torch.nn.functional as F
from torch.utils.data import DataLoader as Dataloader_dsm, Dataset
from torch_geometric.loader import DataLoader as Dataloader_dot
from torch_geometric.nn import MessagePassing, TopKPooling
from torch_geometric.nn import global_mean_pool, global_max_pool
from torch_geometric.utils import degree
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt

# %%
# GCN layer
# cite: https://pytorch-geometric.readthedocs.io/en/latest/notes/create_gnn.html
class GCNConv(MessagePassing):
    def __init__(self, in_channels, out_channels, **kwargs):
        super().__init__(aggr='add', **kwargs)  # "Add" aggregation (Step 5).
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.lin = Linear(in_channels, out_channels)

    def forward(self, x, edge_index):
        # x[N, in_channels]
        # edge_index, _ = add_self_loops(edge_index, num_nodes=x.size(0))
        x = self.lin(x)
        row, col = edge_index

        deg = degree(col, x.size(0), dtype=x.dtype)

        deg_inv_sqrt = deg.pow(-0.5)
        deg_inv_sqrt[deg_inv_sqrt == float('inf')] = 0
        norm = deg_inv_sqrt[row] * deg_inv_sqrt[col]
        return  self.propagate(edge_index, size=(x.size(0), x.size(0)), x=x, norm=norm)

    def message(self, x_j, norm):
        # x_j has shape [E, out_channels]

        # Step 4: Normalize node features.
        return norm.view(-1, 1) * x_j

    def update(self, aggr_out):
        # aggr_out has shape [N, out_channels]
        # Step 6: Return new node embeddings.
        return aggr_out

# %%
class HybridNet(torch.nn.Module):
	def __init__(self, size0, size1):
		super(HybridNet, self).__init__()
		###############################################################################
		# GCN model   																  #
		###############################################################################
		self.conv1 = GCNConv(256, 256)
		self.pool1 = TopKPooling(256, ratio=0.8)
		self.conv2 = GCNConv(256, 256)
		self.pool2 = TopKPooling(256, ratio=0.8)
		self.conv3 = GCNConv(256, 256)
		self.pool3 = TopKPooling(256, ratio=0.8)
		self.conv4 = GCNConv(256, 256)
		self.pool4 = TopKPooling(256, ratio=0.8)
		self.conv5 = GCNConv(256, 256)
		self.pool5 = TopKPooling(256, ratio=0.8)

		self.convAtt1 = torch.nn.Conv1d(in_channels=512, out_channels=64, kernel_size=1, stride=2)
		self.poolAtt1 = torch.nn.MaxPool1d(kernel_size=1, stride=2)
		self.convAtt2 = torch.nn.Conv1d(64, 16, kernel_size=1, stride=2)
		self.poolAtt2 = torch.nn.MaxPool1d(kernel_size=1, stride=2)
		self.convAtt3 = torch.nn.Conv1d(16, 2, kernel_size=1, stride=2)
		self.poolAtt3 = torch.nn.MaxPool1d(kernel_size=1, stride=2)

		self.convAtt4 = torch.nn.Conv1d(2, 16, kernel_size=1, stride=2)
		self.poolAtt4 = torch.nn.MaxPool1d(kernel_size=1, stride=2)
		self.convAtt5 = torch.nn.Conv1d(16, 64, kernel_size=1, stride=2)
		self.poolAtt5 = torch.nn.MaxPool1d(kernel_size=1, stride=2)
		self.convAtt6 = torch.nn.Conv1d(64, 512, kernel_size=1, stride=2)
		self.poolAtt6 = torch.nn.MaxPool1d(kernel_size=1, stride=2)

		###############################################################################
		# textCNN model   															  #
		###############################################################################
		h_input = size0
		w_input = size1
		filter_list = [2, 4, 6, 8, 10, 12, 16, 20]
		num_per_filter = 64
		h_raw = [h_input - i + 1 for i in filter_list]  # 175-filter_size+1: after conv
		filter_list1 = [math.ceil(i / 2) for i in h_raw]  # p = ceil[h_raw / 2]
		self.num_filter = len(filter_list)
		self.conv_t = nn.ModuleList([nn.Conv2d(1, num_per_filter, (cnv_size, w_input)) for cnv_size in filter_list])
		self.max_t = nn.MaxPool2d(kernel_size=(num_per_filter, 1))
		self.avg_t = nn.AvgPool2d(kernel_size=(num_per_filter, 1))
		self.conv_t1 = nn.ModuleList([nn.Conv2d(2, 1, (cnv_size, 1), padding='same') for cnv_size in filter_list1])
		self.sig = nn.Sigmoid()
		h_res = sum(h_raw)  # textCNN_input_feature
		self.lin0_ = torch.nn.Linear(h_res, 512)
		###############################################################################
		# hybrid output   															  #
		###############################################################################
		# x: cfg  t:dsm
		# self.ratio = 0.5
		# r_dot = round(self.ratio * 1024)
		# r_dsm = 1024 - r_dot
        #
		# self.lin0x_ = torch.nn.Linear(512, r_dot)
		# self.lin0t_ = torch.nn.Linear(512, r_dsm)

		self.lin1_ = torch.nn.Linear(1024, 512)
		self.lin2_ = torch.nn.Linear(512, 128)
		self.lin3_ = torch.nn.Linear(128, 64)
		self.lin4_ = torch.nn.Linear(64, 6)
		self.dropout_ = nn.Dropout(0.6)

	def forward(self, x, edge_index, batch, t):
		###############################################################################
		# GCN model :  x, edge_index, batch = data.x, data.edge_index, data.batch	  #
		###############################################################################
		x = F.relu(self.conv1(x, edge_index))
		x, edge_index, _, batch, _, _ = self.pool1(x, edge_index, None, batch)
		x1 = torch.cat([global_max_pool(x, batch), global_mean_pool(x, batch)], dim=1)

		x = F.relu(self.conv2(x, edge_index))
		x, edge_index, _, batch, _, _ = self.pool2(x, edge_index, None, batch)
		x2 = torch.cat([global_max_pool(x, batch), global_mean_pool(x, batch)], dim=1)

		x = F.relu(self.conv3(x, edge_index))
		x, edge_index, _, batch, _, _ = self.pool3(x, edge_index, None, batch)
		x3 = torch.cat([global_max_pool(x, batch), global_mean_pool(x, batch)], dim=1)

		x = F.relu(self.conv4(x, edge_index))
		x, edge_index, _, batch, _, _ = self.pool4(x, edge_index, None, batch)
		x4 = torch.cat([global_max_pool(x, batch), global_mean_pool(x, batch)], dim=1)

		x = F.relu(self.conv5(x, edge_index))
		x, edge_index, _, batch, _, _ = self.pool5(x, edge_index, None, batch)
		x5 = torch.cat([global_max_pool(x, batch), global_mean_pool(x, batch)], dim=1)

		x = x1 + x2 + x3 + x4 + x5

		x = 1 / 5 * x

		sx = x

		x = x.unsqueeze(dim=2)

		# attention
		x = F.relu(self.convAtt1(x))
		x = self.poolAtt1(x)
		x = F.relu(self.convAtt2(x))
		x = self.poolAtt2(x)
		x = F.relu(self.convAtt3(x))
		x = self.poolAtt3(x)

		x = F.relu(self.convAtt4(x))
		x = self.poolAtt4(x)
		x = F.relu(self.convAtt5(x))
		x = self.poolAtt5(x)
		x = F.relu(self.convAtt6(x))
		x = self.poolAtt6(x)
		x = x.squeeze()

		x = (x + 1) * sx

		###############################################################################
		# TextCNN model :  t = batch * h * w										  #
		###############################################################################
		t = torch.unsqueeze(t, 1)
		t = [torch.squeeze(F.relu(conv(t)), 3) for conv in self.conv_t]
		# per_filter * [batch * num_per_filter * h_raw]

		for i in range(0, self.num_filter):
			t[i] = torch.unsqueeze(t[i], 1)
			# [batch * 1 * num_per_filter * h_raw]
			max_ = torch.unsqueeze(torch.squeeze(self.max_t(t[i]), 1), 3)
			avg_ = torch.unsqueeze(torch.squeeze(self.avg_t(t[i]), 1), 3)

			attention_ = torch.cat((max_, avg_), dim=1)
			attention_ = self.sig(self.conv_t1[i](attention_))
			attention_ = torch.unsqueeze(torch.squeeze(attention_, 3), 1)
			t[i] = t[i] * attention_
			t[i] = torch.squeeze(self.max_t(t[i]))
		t = torch.cat(t, dim=1)
		t = torch.squeeze(t)
		t = F.relu(self.lin0_(t))
		###############################################################################
		# hybrid output :  #
		###############################################################################
		# out layer
		# self.lin0x_ = torch.nn.Linear(512, r_dot)
		# self.lin0t_ = torch.nn.Linear(512, r_dsm)
        # if self.ratio != 0.5:
		#   x = F.relu(self.lin0x_(x))
		#   t = F.relu(self.lin0t_(t))

		x = torch.cat((x, t), dim=1)  # 512 + 512

		x = F.relu(self.lin1_(x))
		x = F.relu(self.lin2_(x))
		x = F.relu(self.lin3_(x))
		x = F.dropout(x, p=0.5, training=self.training)
		x = F.log_softmax(self.lin4_(x), dim=-1)

		return x

# %%
class MyDataset(Dataset):
    def __init__(self, dataset_, size_):
        for idx, data_ in enumerate(dataset_):
            data_len_ = len(data_)
            if data_len_ < size_[0]:
                pad = torch.zeros(size_[0] - data_len_, size_[1])
                dataset_[idx] = torch.cat((data_, pad), dim=0)
            else:
                dataset_[idx] = data_[:size_[0]]
        self.dateset = dataset_
        self.size = size_

    def __len__(self):
        return len(self.dateset)

    def __getitem__(self, idx):
        return self.dateset[idx]

# %%
# init model
size_ = [175, 45]
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = HybridNet(size_[0], size_[1]).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
def train(Train_dot_loader, Train_dsm_loader):
	model.train()
	loss_all = 0
	iter_loader = iter(Train_dsm_loader)
	for data in Train_dot_loader:
		data1 = next(iter_loader)
		data1 = data1.to(device)
		data = data.to(device)

		optimizer.zero_grad()

		x, edge_index, batch = data.x, data.edge_index, data.batch
		output = model(x, edge_index, batch, data1)
		loss = F.nll_loss(output, data.y)
		loss.backward()
		loss_all += data.num_graphs * loss.item()
		optimizer.step()
	return loss_all / len(Train_dot_loader.dataset)

# %%
def test(loader0, loader1):
	# loader0:dot loader1:dsm
	model.eval()
	correct = 0
	iter_loader = iter(loader1)
	pred_list, true_list = np.array(0), np.array(0)
	for data0 in loader0:
		data1 = next(iter_loader)
		data1 = data1.to(device)
		data0 = data0.to(device)
		optimizer.zero_grad()
		x, edge_index, batch = data0.x, data0.edge_index, data0.batch
		y_pred = model(x, edge_index, batch, data1)
		y_pred = y_pred.max(dim=1)[1]
		pred_list = np.append(pred_list, y_pred.to('cpu').numpy())
		true_list = np.append(true_list, data0.y.to('cpu').numpy())
		correct += y_pred.eq(data0.y).sum().item()
	acc = correct / len(loader0.dataset)
	return round(acc, 6), pred_list, true_list

# %%
# main:
start_time = time.time()

with open(rf'D:\Desktop\hybrid-SVD\dataset\multi_test.pk', 'rb') as f_:
	cur_dataset = pickle.load(f_)
	random.shuffle(cur_dataset)
	test_dsm = []
	test_dot = []
	for d in cur_dataset:
		test_dot.append(d[0])
		test_dsm.append(d[1])
	del cur_dataset
	gc.collect()
	Test_dot_loader = Dataloader_dot(test_dot, batch_size=32, shuffle=False, drop_last=True)
	Test_dsm_loader = Dataloader_dsm(MyDataset(test_dsm, size_), batch_size=32, shuffle=False, drop_last=True)

all_loss_list = []
avg_loss_list = []
acc_list = []
best_model = None
best_acc = {'acc': 0, 'epoch': 0}

for epoch in range(0, 80):
	print("===>epoch:{:03d}===>".format(epoch))
	loss_list = []
	for i_ in range(0, 4):
		with open(rf'D:\Desktop\hybrid-SVD\dataset\multi_train{i_}.pk', 'rb') as f_:
			cur_dataset = pickle.load(f_)
			random.shuffle(cur_dataset)
			train_dsm = []
			train_dot = []
			for d in cur_dataset:
				train_dot.append(d[0])
				train_dsm.append(d[1])
			del cur_dataset
			gc.collect()
			Train_dot_loader = Dataloader_dot(train_dot, batch_size=32, shuffle=False, drop_last=True)
			Train_dsm_loader = Dataloader_dsm(MyDataset(train_dsm, size_), batch_size=32, shuffle=False, drop_last=True)
			loss = train(Train_dot_loader, Train_dsm_loader)
			loss_list.append(loss)
			all_loss_list.append(loss)
			if epoch % 1 == 0:
				acc, _, _ = test(Train_dot_loader, Train_dsm_loader)
				print("#train_set:{:d}, loss:{:.5f}, Train_acc:{:.5f}".format(i_, loss, acc))
			if epoch % 1 == 0 and i_ == 3:
				avg_loss = math.fsum(loss_list) / 4
				avg_loss_list.append(avg_loss)
				print("avg loss:{:.5f}".format(avg_loss))

	if epoch % 1 == 0:
		acc, y_pred, y_true = test(Test_dot_loader, Test_dsm_loader)
		acc_list.append(acc)
		if acc > best_acc['acc']:
			best_acc['acc'], best_acc['epoch'] = acc, epoch
			best_model = model
		print("Test_acc:{:.5f}".format(acc))
		measure_result = classification_report(y_true[1:], y_pred[1:])
		print('measure_result = \n', measure_result)
		print("Time span:{:.5f}".format(time.time() - start_time))

print("Total time span:{:.5f}".format(time.time() - start_time))
# Out:
# ===>epoch:000===>
# D:\Develop\Miniconda\envs\pytorch\lib\site-packages\torch\nn\modules\conv.py:453: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at  C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\Convolution.cpp:883.)
#   return F.conv2d(input, weight, bias, self.stride,
# #train_set:0, loss:1.22793, Train_acc:0.61602
# #train_set:1, loss:0.73739, Train_acc:0.79883
# #train_set:2, loss:0.58999, Train_acc:0.81914
# #train_set:3, loss:0.46780, Train_acc:0.86953
# avg loss:0.75578
# Test_acc:0.86776
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.98      0.91      0.94      1297
#            1       0.98      0.84      0.90       218
#            2       0.34      0.48      0.40       133
#            3       0.32      0.26      0.29       153
#            4       0.87      0.99      0.93       669
#            5       0.96      0.94      0.95       154
#
#     accuracy                           0.87      2624
#    macro avg       0.74      0.74      0.73      2624
# weighted avg       0.88      0.87      0.87      2624
#
# Time span:69.83447
# ===>epoch:001===>
# #train_set:0, loss:0.34439, Train_acc:0.84844
# #train_set:1, loss:0.33661, Train_acc:0.90391
# #train_set:2, loss:0.30147, Train_acc:0.87148
# #train_set:3, loss:0.30356, Train_acc:0.90078
# avg loss:0.32151
# Test_acc:0.90549
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96      1297
#            1       0.88      0.99      0.93       218
#            2       0.64      0.05      0.10       133
#            3       0.46      0.90      0.60       153
#            4       0.95      0.99      0.97       669
#            5       1.00      0.95      0.97       154
#
#     accuracy                           0.91      2624
#    macro avg       0.82      0.80      0.76      2624
# weighted avg       0.92      0.91      0.90      2624
#
# Time span:130.26766
# ===>epoch:002===>
# #train_set:0, loss:0.22512, Train_acc:0.92344
# #train_set:1, loss:0.20184, Train_acc:0.92539
# #train_set:2, loss:0.21985, Train_acc:0.92773
# #train_set:3, loss:0.17149, Train_acc:0.92734
# avg loss:0.20458
# Test_acc:0.92188
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96      1297
#            1       0.97      0.89      0.93       218
#            2       0.61      0.33      0.43       133
#            3       0.57      0.76      0.65       153
#            4       0.96      0.99      0.97       669
#            5       0.97      0.99      0.98       154
#
#     accuracy                           0.92      2624
#    macro avg       0.84      0.82      0.82      2624
# weighted avg       0.92      0.92      0.92      2624
#
# Time span:189.94449
# ===>epoch:003===>
# #train_set:0, loss:0.18591, Train_acc:0.90938
# #train_set:1, loss:0.17786, Train_acc:0.93711
# #train_set:2, loss:0.17487, Train_acc:0.94180
# #train_set:3, loss:0.14081, Train_acc:0.95352
# avg loss:0.16986
# Test_acc:0.93979
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97      1297
#            1       0.96      0.88      0.92       218
#            2       0.61      0.86      0.72       133
#            3       0.98      0.56      0.71       153
#            4       0.98      0.97      0.98       669
#            5       0.98      1.00      0.99       154
#
#     accuracy                           0.94      2624
#    macro avg       0.91      0.88      0.88      2624
# weighted avg       0.95      0.94      0.94      2624
#
# Time span:249.59156
# ===>epoch:004===>
# #train_set:0, loss:0.14920, Train_acc:0.95195
# #train_set:1, loss:0.15918, Train_acc:0.94766
# #train_set:2, loss:0.16712, Train_acc:0.95352
# #train_set:3, loss:0.12408, Train_acc:0.96094
# avg loss:0.14990
# Test_acc:0.94474
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97      1297
#            1       0.93      0.94      0.94       218
#            2       0.64      0.80      0.71       133
#            3       0.94      0.63      0.75       153
#            4       0.99      0.97      0.98       669
#            5       0.98      0.99      0.99       154
#
#     accuracy                           0.94      2624
#    macro avg       0.91      0.89      0.89      2624
# weighted avg       0.95      0.94      0.94      2624
#
# Time span:309.82131
# ===>epoch:005===>
# #train_set:0, loss:0.14682, Train_acc:0.93359
# #train_set:1, loss:0.19024, Train_acc:0.95000
# #train_set:2, loss:0.11356, Train_acc:0.96602
# #train_set:3, loss:0.14162, Train_acc:0.96172
# avg loss:0.14806
# Test_acc:0.95579
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98      1297
#            1       0.96      0.99      0.98       218
#            2       0.64      0.91      0.75       133
#            3       0.97      0.63      0.77       153
#            4       0.98      0.99      0.98       669
#            5       1.00      0.98      0.99       154
#
#     accuracy                           0.96      2624
#    macro avg       0.92      0.91      0.91      2624
# weighted avg       0.96      0.96      0.96      2624
#
# Time span:369.59552
# ===>epoch:006===>
# #train_set:0, loss:0.10134, Train_acc:0.96758
# #train_set:1, loss:0.14845, Train_acc:0.95117
# #train_set:2, loss:0.10218, Train_acc:0.96367
# #train_set:3, loss:0.11055, Train_acc:0.96641
# avg loss:0.11563
# Test_acc:0.95122
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97      1297
#            1       0.94      0.99      0.96       218
#            2       0.64      0.86      0.73       133
#            3       0.90      0.66      0.76       153
#            4       0.99      0.98      0.98       669
#            5       1.00      0.99      0.99       154
#
#     accuracy                           0.95      2624
#    macro avg       0.91      0.91      0.90      2624
# weighted avg       0.96      0.95      0.95      2624
#
# Time span:429.38210
# ===>epoch:007===>
# #train_set:0, loss:0.09699, Train_acc:0.97461
# #train_set:1, loss:0.07771, Train_acc:0.97031
# #train_set:2, loss:0.08231, Train_acc:0.96445
# #train_set:3, loss:0.07950, Train_acc:0.96953
# avg loss:0.08413
# Test_acc:0.95427
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97      1297
#            1       0.95      0.95      0.95       218
#            2       0.68      0.77      0.72       133
#            3       0.94      0.66      0.78       153
#            4       1.00      0.99      0.99       669
#            5       0.99      0.99      0.99       154
#
#     accuracy                           0.95      2624
#    macro avg       0.92      0.89      0.90      2624
# weighted avg       0.96      0.95      0.95      2624
#
# Time span:488.78027
# ===>epoch:008===>
# #train_set:0, loss:0.08669, Train_acc:0.96484
# #train_set:1, loss:0.09324, Train_acc:0.96562
# #train_set:2, loss:0.08597, Train_acc:0.96875
# #train_set:3, loss:0.12554, Train_acc:0.96289
# avg loss:0.09786
# Test_acc:0.94969
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      1297
#            1       0.97      0.94      0.95       218
#            2       0.67      0.74      0.70       133
#            3       0.97      0.63      0.77       153
#            4       0.97      0.98      0.98       669
#            5       0.98      0.99      0.99       154
#
#     accuracy                           0.95      2624
#    macro avg       0.92      0.88      0.89      2624
# weighted avg       0.95      0.95      0.95      2624
#
# Time span:548.21531
# ===>epoch:009===>
# #train_set:0, loss:0.10505, Train_acc:0.97305
# #train_set:1, loss:0.08940, Train_acc:0.95117
# #train_set:2, loss:0.09375, Train_acc:0.96641
# #train_set:3, loss:0.07155, Train_acc:0.97461
# avg loss:0.08994
# Test_acc:0.95998
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      1297
#            1       1.00      0.94      0.97       218
#            2       0.73      0.70      0.72       133
#            3       0.81      0.76      0.79       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.96      2624
#    macro avg       0.92      0.90      0.91      2624
# weighted avg       0.96      0.96      0.96      2624
#
# Time span:607.89669
# ===>epoch:010===>
# #train_set:0, loss:0.07018, Train_acc:0.97266
# #train_set:1, loss:0.07241, Train_acc:0.97344
# #train_set:2, loss:0.06805, Train_acc:0.97070
# #train_set:3, loss:0.07628, Train_acc:0.96602
# avg loss:0.07173
# Test_acc:0.95312
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98      1297
#            1       0.94      0.96      0.95       218
#            2       0.67      0.80      0.73       133
#            3       0.91      0.65      0.76       153
#            4       0.98      0.99      0.99       669
#            5       1.00      0.99      0.99       154
#
#     accuracy                           0.95      2624
#    macro avg       0.91      0.90      0.90      2624
# weighted avg       0.96      0.95      0.95      2624
#
# Time span:668.41714
# ===>epoch:011===>
# #train_set:0, loss:0.10915, Train_acc:0.97148
# #train_set:1, loss:0.07392, Train_acc:0.97500
# #train_set:2, loss:0.06982, Train_acc:0.94688
# #train_set:3, loss:0.07813, Train_acc:0.97500
# avg loss:0.08275
# Test_acc:0.95694
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      1297
#            1       0.97      0.96      0.96       218
#            2       0.66      0.86      0.75       133
#            3       0.93      0.62      0.75       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.96      2624
#    macro avg       0.92      0.90      0.90      2624
# weighted avg       0.96      0.96      0.96      2624
#
# Time span:727.92937
# ===>epoch:012===>
# #train_set:0, loss:0.08093, Train_acc:0.97109
# #train_set:1, loss:0.08367, Train_acc:0.96953
# #train_set:2, loss:0.07044, Train_acc:0.97422
# #train_set:3, loss:0.09594, Train_acc:0.96211
# avg loss:0.08275
# Test_acc:0.95084
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      1297
#            1       1.00      0.94      0.97       218
#            2       0.69      0.79      0.73       133
#            3       0.90      0.69      0.78       153
#            4       1.00      0.95      0.98       669
#            5       0.97      0.99      0.98       154
#
#     accuracy                           0.95      2624
#    macro avg       0.92      0.89      0.90      2624
# weighted avg       0.95      0.95      0.95      2624
#
# Time span:787.56735
# ===>epoch:013===>
# #train_set:0, loss:0.09141, Train_acc:0.96953
# #train_set:1, loss:0.05886, Train_acc:0.97539
# #train_set:2, loss:0.07464, Train_acc:0.97148
# #train_set:3, loss:0.06822, Train_acc:0.97969
# avg loss:0.07328
# Test_acc:0.96380
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      1297
#            1       0.98      0.94      0.96       218
#            2       0.74      0.84      0.79       133
#            3       0.89      0.76      0.82       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.96      2624
#    macro avg       0.93      0.92      0.92      2624
# weighted avg       0.96      0.96      0.96      2624
#
# Time span:847.75536
# ===>epoch:014===>
# #train_set:0, loss:0.06062, Train_acc:0.97539
# #train_set:1, loss:0.05572, Train_acc:0.97539
# #train_set:2, loss:0.04870, Train_acc:0.97617
# #train_set:3, loss:0.05382, Train_acc:0.97305
# avg loss:0.05471
# Test_acc:0.96303
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      1297
#            1       0.94      1.00      0.97       218
#            2       0.68      0.88      0.77       133
#            3       0.92      0.66      0.77       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.96      2624
#    macro avg       0.92      0.92      0.91      2624
# weighted avg       0.97      0.96      0.96      2624
#
# Time span:908.10154
# ===>epoch:015===>
# #train_set:0, loss:0.09182, Train_acc:0.96797
# #train_set:1, loss:0.07606, Train_acc:0.97891
# #train_set:2, loss:0.07852, Train_acc:0.96523
# #train_set:3, loss:0.06344, Train_acc:0.98008
# avg loss:0.07746
# Test_acc:0.95503
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      1297
#            1       0.97      0.98      0.97       218
#            2       0.68      0.72      0.70       133
#            3       0.85      0.72      0.78       153
#            4       1.00      0.98      0.99       669
#            5       1.00      0.96      0.98       154
#
#     accuracy                           0.96      2624
#    macro avg       0.91      0.89      0.90      2624
# weighted avg       0.96      0.96      0.95      2624
#
# Time span:967.68932
# ===>epoch:016===>
# #train_set:0, loss:0.08001, Train_acc:0.97188
# #train_set:1, loss:0.08116, Train_acc:0.96914
# #train_set:2, loss:0.10161, Train_acc:0.97109
# #train_set:3, loss:0.16153, Train_acc:0.98320
# avg loss:0.10608
# Test_acc:0.96227
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      1297
#            1       0.98      0.95      0.97       218
#            2       0.75      0.74      0.74       133
#            3       0.84      0.81      0.83       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.98      0.99       154
#
#     accuracy                           0.96      2624
#    macro avg       0.92      0.91      0.92      2624
# weighted avg       0.96      0.96      0.96      2624
#
# Time span:1027.60341
# ===>epoch:017===>
# #train_set:0, loss:0.07605, Train_acc:0.98203
# #train_set:1, loss:0.06053, Train_acc:0.98164
# #train_set:2, loss:0.04320, Train_acc:0.98438
# #train_set:3, loss:0.04587, Train_acc:0.97383
# avg loss:0.05641
# Test_acc:0.96570
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      1297
#            1       1.00      0.94      0.97       218
#            2       0.97      0.57      0.72       133
#            3       0.75      0.97      0.85       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.97      2624
#    macro avg       0.95      0.91      0.92      2624
# weighted avg       0.97      0.97      0.96      2624
#
# Time span:1087.16610
# ===>epoch:018===>
# #train_set:0, loss:0.05710, Train_acc:0.97969
# #train_set:1, loss:0.09284, Train_acc:0.96328
# #train_set:2, loss:0.07292, Train_acc:0.98242
# #train_set:3, loss:0.05149, Train_acc:0.98242
# avg loss:0.06859
# Test_acc:0.96951
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      1297
#            1       1.00      0.94      0.97       218
#            2       0.83      0.78      0.80       133
#            3       0.82      0.95      0.88       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.97      2624
#    macro avg       0.94      0.94      0.94      2624
# weighted avg       0.97      0.97      0.97      2624
#
# Time span:1147.03627
# ===>epoch:019===>
# #train_set:0, loss:0.05023, Train_acc:0.98125
# #train_set:1, loss:0.05214, Train_acc:0.98359
# #train_set:2, loss:0.04483, Train_acc:0.98438
# #train_set:3, loss:0.04529, Train_acc:0.98164
# avg loss:0.04812
# Test_acc:0.96380
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      1297
#            1       1.00      0.94      0.97       218
#            2       0.71      0.83      0.77       133
#            3       0.84      0.82      0.83       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.96      2624
#    macro avg       0.92      0.93      0.92      2624
# weighted avg       0.97      0.96      0.96      2624
#
# Time span:1207.13282
# ===>epoch:020===>
# #train_set:0, loss:0.04164, Train_acc:0.98398
# #train_set:1, loss:0.03773, Train_acc:0.98555
# #train_set:2, loss:0.04239, Train_acc:0.98086
# #train_set:3, loss:0.04639, Train_acc:0.97539
# avg loss:0.04204
# Test_acc:0.97180
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98      1297
#            1       0.96      1.00      0.98       218
#            2       0.80      0.83      0.81       133
#            3       0.86      0.95      0.90       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.97      2624
#    macro avg       0.93      0.96      0.94      2624
# weighted avg       0.97      0.97      0.97      2624
#
# Time span:1267.07701
# ===>epoch:021===>
# #train_set:0, loss:0.04119, Train_acc:0.98477
# #train_set:1, loss:0.03793, Train_acc:0.98750
# #train_set:2, loss:0.08164, Train_acc:0.98359
# #train_set:3, loss:0.04820, Train_acc:0.98438
# avg loss:0.05224
# Test_acc:0.97294
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      1297
#            1       1.00      0.94      0.97       218
#            2       0.82      0.86      0.84       133
#            3       0.92      0.86      0.89       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.97      2624
#    macro avg       0.95      0.94      0.94      2624
# weighted avg       0.97      0.97      0.97      2624
#
# Time span:1326.82166
# ===>epoch:022===>
# #train_set:0, loss:0.06583, Train_acc:0.96680
# #train_set:1, loss:0.12654, Train_acc:0.97891
# #train_set:2, loss:0.05317, Train_acc:0.98281
# #train_set:3, loss:0.10463, Train_acc:0.98320
# avg loss:0.08754
# Test_acc:0.97370
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      1297
#            1       1.00      0.94      0.97       218
#            2       0.79      0.95      0.86       133
#            3       0.93      0.84      0.88       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      0.99       154
#
#     accuracy                           0.97      2624
#    macro avg       0.95      0.95      0.95      2624
# weighted avg       0.98      0.97      0.97      2624
#
# Time span:1386.40379
# ===>epoch:023===>
# #train_set:0, loss:0.04609, Train_acc:0.98242
# #train_set:1, loss:0.05098, Train_acc:0.98477
# #train_set:2, loss:0.06133, Train_acc:0.97500
# #train_set:3, loss:0.04933, Train_acc:0.98359
# avg loss:0.05193
# Test_acc:0.96837
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      1297
#            1       1.00      0.94      0.97       218
#            2       0.90      0.68      0.77       133
#            3       0.84      0.93      0.88       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.97      2624
#    macro avg       0.95      0.92      0.93      2624
# weighted avg       0.97      0.97      0.97      2624
#
# Time span:1446.28766
# ===>epoch:024===>
# #train_set:0, loss:0.06996, Train_acc:0.98164
# #train_set:1, loss:0.04358, Train_acc:0.98320
# #train_set:2, loss:0.03994, Train_acc:0.98203
# #train_set:3, loss:0.03890, Train_acc:0.98359
# avg loss:0.04809
# Test_acc:0.97408
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      1297
#            1       1.00      0.94      0.97       218
#            2       0.92      0.76      0.83       133
#            3       0.88      0.94      0.91       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.97      2624
#    macro avg       0.96      0.94      0.95      2624
# weighted avg       0.97      0.97      0.97      2624
#
# Time span:1506.14893
# ===>epoch:025===>
# #train_set:0, loss:0.03814, Train_acc:0.98633
# #train_set:1, loss:0.03721, Train_acc:0.98672
# #train_set:2, loss:0.04230, Train_acc:0.98750
# #train_set:3, loss:0.03791, Train_acc:0.98516
# avg loss:0.03889
# Test_acc:0.97294
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      1297
#            1       0.98      0.95      0.97       218
#            2       0.89      0.77      0.83       133
#            3       0.84      0.96      0.90       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.97      2624
#    macro avg       0.95      0.94      0.94      2624
# weighted avg       0.97      0.97      0.97      2624
#
# Time span:1565.53770
# ===>epoch:026===>
# #train_set:0, loss:0.03706, Train_acc:0.98477
# #train_set:1, loss:0.03533, Train_acc:0.97383
# #train_set:2, loss:0.17736, Train_acc:0.98008
# #train_set:3, loss:0.09403, Train_acc:0.97656
# avg loss:0.08595
# Test_acc:0.96380
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      1297
#            1       0.99      0.91      0.95       218
#            2       0.89      0.67      0.76       133
#            3       0.84      0.93      0.88       153
#            4       1.00      0.98      0.99       669
#            5       0.97      0.99      0.98       154
#
#     accuracy                           0.96      2624
#    macro avg       0.94      0.91      0.92      2624
# weighted avg       0.96      0.96      0.96      2624
#
# Time span:1624.62461
# ===>epoch:027===>
# #train_set:0, loss:0.08765, Train_acc:0.98438
# #train_set:1, loss:0.07308, Train_acc:0.98359
# #train_set:2, loss:0.05173, Train_acc:0.98516
# #train_set:3, loss:0.04482, Train_acc:0.98281
# avg loss:0.06432
# Test_acc:0.97027
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      1297
#            1       0.94      1.00      0.97       218
#            2       0.84      0.75      0.79       133
#            3       0.89      0.88      0.89       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.97      2624
#    macro avg       0.94      0.93      0.94      2624
# weighted avg       0.97      0.97      0.97      2624
#
# Time span:1683.95203
# ===>epoch:028===>
# #train_set:0, loss:0.03857, Train_acc:0.98750
# #train_set:1, loss:0.03607, Train_acc:0.98711
# #train_set:2, loss:0.03475, Train_acc:0.98633
# #train_set:3, loss:0.03814, Train_acc:0.98633
# avg loss:0.03688
# Test_acc:0.97485
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      1297
#            1       1.00      0.96      0.98       218
#            2       0.82      0.87      0.84       133
#            3       0.96      0.84      0.90       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.97      2624
#    macro avg       0.96      0.94      0.95      2624
# weighted avg       0.98      0.97      0.97      2624
#
# Time span:1743.92212
# ===>epoch:029===>
# #train_set:0, loss:0.03434, Train_acc:0.98711
# #train_set:1, loss:0.03837, Train_acc:0.98438
# #train_set:2, loss:0.04739, Train_acc:0.98398
# #train_set:3, loss:0.07201, Train_acc:0.98242
# avg loss:0.04803
# Test_acc:0.97180
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      1297
#            1       1.00      0.94      0.97       218
#            2       0.78      0.90      0.84       133
#            3       0.91      0.87      0.89       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.97      2624
#    macro avg       0.95      0.95      0.94      2624
# weighted avg       0.97      0.97      0.97      2624
#
# Time span:1804.31550
# ===>epoch:030===>
# #train_set:0, loss:0.07001, Train_acc:0.98398
# #train_set:1, loss:0.03599, Train_acc:0.98516
# #train_set:2, loss:0.03817, Train_acc:0.98555
# #train_set:3, loss:0.03075, Train_acc:0.98672
# avg loss:0.04373
# Test_acc:0.97104
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      1297
#            1       0.95      0.98      0.96       218
#            2       0.85      0.78      0.82       133
#            3       0.86      0.92      0.89       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.97      2624
#    macro avg       0.94      0.94      0.94      2624
# weighted avg       0.97      0.97      0.97      2624
#
# Time span:1864.03863
# ===>epoch:031===>
# #train_set:0, loss:0.03678, Train_acc:0.98672
# #train_set:1, loss:0.04125, Train_acc:0.98750
# #train_set:2, loss:0.03554, Train_acc:0.98359
# #train_set:3, loss:0.03595, Train_acc:0.98750
# avg loss:0.03738
# Test_acc:0.97447
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      1297
#            1       1.00      0.94      0.97       218
#            2       0.85      0.86      0.86       133
#            3       0.92      0.88      0.90       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.97      2624
#    macro avg       0.96      0.94      0.95      2624
# weighted avg       0.97      0.97      0.97      2624
#
# Time span:1923.21349
# ===>epoch:032===>
# #train_set:0, loss:0.03563, Train_acc:0.98750
# #train_set:1, loss:0.03044, Train_acc:0.98633
# #train_set:2, loss:0.04933, Train_acc:0.98750
# #train_set:3, loss:0.03343, Train_acc:0.98672
# avg loss:0.03721
# Test_acc:0.97104
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      1297
#            1       0.99      0.94      0.96       218
#            2       0.80      0.85      0.82       133
#            3       0.92      0.85      0.88       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.97      2624
#    macro avg       0.95      0.94      0.94      2624
# weighted avg       0.97      0.97      0.97      2624
#
# Time span:1982.72270
# ===>epoch:033===>
# #train_set:0, loss:0.02925, Train_acc:0.98789
# #train_set:1, loss:0.03305, Train_acc:0.98906
# #train_set:2, loss:0.03087, Train_acc:0.98672
# #train_set:3, loss:0.03071, Train_acc:0.98281
# avg loss:0.03097
# Test_acc:0.97485
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      1297
#            1       0.94      1.00      0.97       218
#            2       0.89      0.80      0.85       133
#            3       0.83      0.96      0.89       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.97      2624
#    macro avg       0.94      0.95      0.95      2624
# weighted avg       0.98      0.97      0.97      2624
#
# Time span:2042.67286
# ===>epoch:034===>
# #train_set:0, loss:0.03078, Train_acc:0.98633
# #train_set:1, loss:0.05262, Train_acc:0.97383
# #train_set:2, loss:0.05208, Train_acc:0.98125
# #train_set:3, loss:0.05386, Train_acc:0.98008
# avg loss:0.04733
# Test_acc:0.97142
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      1297
#            1       1.00      0.94      0.97       218
#            2       0.83      0.82      0.83       133
#            3       0.94      0.88      0.91       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.97      2624
#    macro avg       0.96      0.94      0.95      2624
# weighted avg       0.97      0.97      0.97      2624
#
# Time span:2102.44407
# ===>epoch:035===>
# #train_set:0, loss:0.06684, Train_acc:0.97383
# #train_set:1, loss:0.09149, Train_acc:0.98125
# #train_set:2, loss:0.11046, Train_acc:0.98125
# #train_set:3, loss:0.04990, Train_acc:0.98750
# avg loss:0.07967
# Test_acc:0.97066
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      1297
#            1       0.99      0.95      0.97       218
#            2       0.83      0.78      0.81       133
#            3       0.86      0.90      0.88       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.97      2624
#    macro avg       0.94      0.93      0.94      2624
# weighted avg       0.97      0.97      0.97      2624
#
# Time span:2162.00262
# ===>epoch:036===>
# #train_set:0, loss:0.07597, Train_acc:0.98516
# #train_set:1, loss:0.04262, Train_acc:0.98516
# #train_set:2, loss:0.04740, Train_acc:0.98828
# #train_set:3, loss:0.03823, Train_acc:0.98672
# avg loss:0.05106
# Test_acc:0.96951
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      1297
#            1       1.00      0.94      0.97       218
#            2       0.86      0.72      0.78       133
#            3       0.85      0.90      0.87       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.97      2624
#    macro avg       0.95      0.92      0.93      2624
# weighted avg       0.97      0.97      0.97      2624
#
# Time span:2221.30068
# ===>epoch:037===>
# #train_set:0, loss:0.03410, Train_acc:0.98477
# #train_set:1, loss:0.03192, Train_acc:0.98594
# #train_set:2, loss:0.03803, Train_acc:0.98555
# #train_set:3, loss:0.03648, Train_acc:0.98398
# avg loss:0.03513
# Test_acc:0.97599
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      1297
#            1       0.95      1.00      0.97       218
#            2       0.88      0.84      0.86       133
#            3       0.88      0.90      0.89       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.98      2624
#    macro avg       0.95      0.95      0.95      2624
# weighted avg       0.98      0.98      0.98      2624
#
# Time span:2281.21181
# ===>epoch:038===>
# #train_set:0, loss:0.04318, Train_acc:0.98633
# #train_set:1, loss:0.03225, Train_acc:0.98867
# #train_set:2, loss:0.03848, Train_acc:0.98477
# #train_set:3, loss:0.03191, Train_acc:0.98672
# avg loss:0.03646
# Test_acc:0.97370
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      1297
#            1       1.00      0.94      0.97       218
#            2       0.87      0.78      0.83       133
#            3       0.86      0.93      0.89       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.97      2624
#    macro avg       0.95      0.94      0.94      2624
# weighted avg       0.97      0.97      0.97      2624
#
# Time span:2341.31318
# ===>epoch:039===>
# #train_set:0, loss:0.03024, Train_acc:0.98828
# #train_set:1, loss:0.02980, Train_acc:0.98711
# #train_set:2, loss:0.04893, Train_acc:0.98320
# #train_set:3, loss:0.11292, Train_acc:0.98320
# avg loss:0.05547
# Test_acc:0.97370
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      1297
#            1       0.96      1.00      0.98       218
#            2       0.83      0.83      0.83       133
#            3       0.89      0.86      0.88       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      0.99       154
#
#     accuracy                           0.97      2624
#    macro avg       0.94      0.94      0.94      2624
# weighted avg       0.97      0.97      0.97      2624
#
# Time span:2401.03525
# ===>epoch:040===>
# #train_set:0, loss:0.03963, Train_acc:0.98750
# #train_set:1, loss:0.03329, Train_acc:0.98867
# #train_set:2, loss:0.11971, Train_acc:0.98125
# #train_set:3, loss:0.06778, Train_acc:0.98125
# avg loss:0.06510
# Test_acc:0.96684
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      1297
#            1       0.98      0.96      0.97       218
#            2       0.93      0.61      0.74       133
#            3       0.73      0.99      0.84       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.97      0.99       154
#
#     accuracy                           0.97      2624
#    macro avg       0.94      0.92      0.92      2624
# weighted avg       0.97      0.97      0.97      2624
#
# Time span:2461.06912
# ===>epoch:041===>
# #train_set:0, loss:0.05763, Train_acc:0.98438
# #train_set:1, loss:0.05780, Train_acc:0.98359
# #train_set:2, loss:0.03929, Train_acc:0.98828
# #train_set:3, loss:0.03413, Train_acc:0.98594
# avg loss:0.04721
# Test_acc:0.97561
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      1297
#            1       1.00      0.94      0.97       218
#            2       0.89      0.82      0.85       133
#            3       0.88      0.95      0.91       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.98      2624
#    macro avg       0.96      0.95      0.95      2624
# weighted avg       0.98      0.98      0.98      2624
#
# Time span:2520.47752
# ===>epoch:042===>
# #train_set:0, loss:0.03652, Train_acc:0.98516
# #train_set:1, loss:0.03057, Train_acc:0.98672
# #train_set:2, loss:0.03129, Train_acc:0.98867
# #train_set:3, loss:0.02921, Train_acc:0.98672
# avg loss:0.03190
# Test_acc:0.97561
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      1297
#            1       1.00      0.95      0.98       218
#            2       0.92      0.77      0.84       133
#            3       0.85      0.95      0.90       153
#            4       1.00      0.99      0.99       669
#            5       0.99      0.99      0.99       154
#
#     accuracy                           0.98      2624
#    macro avg       0.96      0.94      0.95      2624
# weighted avg       0.98      0.98      0.98      2624
#
# Time span:2580.57098
# ===>epoch:043===>
# #train_set:0, loss:0.06282, Train_acc:0.97500
# #train_set:1, loss:0.07067, Train_acc:0.98594
# #train_set:2, loss:0.04957, Train_acc:0.98750
# #train_set:3, loss:0.03449, Train_acc:0.98672
# avg loss:0.05439
# Test_acc:0.97828
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      1297
#            1       1.00      0.95      0.98       218
#            2       0.85      0.91      0.88       133
#            3       0.92      0.88      0.90       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.98      2624
#    macro avg       0.96      0.95      0.95      2624
# weighted avg       0.98      0.98      0.98      2624
#
# Time span:2640.06340
# ===>epoch:044===>
# #train_set:0, loss:0.03438, Train_acc:0.98594
# #train_set:1, loss:0.03381, Train_acc:0.98672
# #train_set:2, loss:0.04286, Train_acc:0.98906
# #train_set:3, loss:0.05191, Train_acc:0.98711
# avg loss:0.04074
# Test_acc:0.97866
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      1297
#            1       1.00      0.96      0.98       218
#            2       0.93      0.80      0.86       133
#            3       0.88      0.97      0.93       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.98      2624
#    macro avg       0.97      0.95      0.96      2624
# weighted avg       0.98      0.98      0.98      2624
#
# Time span:2699.39363
# ===>epoch:045===>
# #train_set:0, loss:0.03044, Train_acc:0.98828
# #train_set:1, loss:0.03832, Train_acc:0.99023
# #train_set:2, loss:0.03352, Train_acc:0.98789
# #train_set:3, loss:0.06669, Train_acc:0.97734
# avg loss:0.04224
# Test_acc:0.96951
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      1297
#            1       1.00      0.94      0.97       218
#            2       0.91      0.72      0.81       133
#            3       0.85      0.97      0.90       153
#            4       1.00      0.97      0.98       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.97      2624
#    macro avg       0.95      0.93      0.94      2624
# weighted avg       0.97      0.97      0.97      2624
#
# Time span:2759.05717
# ===>epoch:046===>
# #train_set:0, loss:0.05160, Train_acc:0.98477
# #train_set:1, loss:0.03113, Train_acc:0.98828
# #train_set:2, loss:0.04200, Train_acc:0.98320
# #train_set:3, loss:0.04044, Train_acc:0.98594
# avg loss:0.04129
# Test_acc:0.97523
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      1297
#            1       1.00      0.95      0.98       218
#            2       0.88      0.80      0.84       133
#            3       0.85      0.96      0.90       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.98      2624
#    macro avg       0.95      0.95      0.95      2624
# weighted avg       0.98      0.98      0.98      2624
#
# Time span:2818.52866
# ===>epoch:047===>
# #train_set:0, loss:0.03399, Train_acc:0.98281
# #train_set:1, loss:0.03132, Train_acc:0.98711
# #train_set:2, loss:0.04730, Train_acc:0.98789
# #train_set:3, loss:0.04167, Train_acc:0.98789
# avg loss:0.03857
# Test_acc:0.97408
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      1297
#            1       1.00      0.95      0.98       218
#            2       0.90      0.74      0.81       133
#            3       0.85      0.95      0.90       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.97      2624
#    macro avg       0.95      0.94      0.94      2624
# weighted avg       0.97      0.97      0.97      2624
#
# Time span:2878.47283
# ===>epoch:048===>
# #train_set:0, loss:0.03223, Train_acc:0.98594
# #train_set:1, loss:0.03198, Train_acc:0.98984
# #train_set:2, loss:0.03725, Train_acc:0.98477
# #train_set:3, loss:0.03444, Train_acc:0.98828
# avg loss:0.03398
# Test_acc:0.97713
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      1297
#            1       0.99      0.96      0.98       218
#            2       0.87      0.84      0.85       133
#            3       0.89      0.93      0.91       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.98      2624
#    macro avg       0.95      0.95      0.95      2624
# weighted avg       0.98      0.98      0.98      2624
#
# Time span:2937.94255
# ===>epoch:049===>
# #train_set:0, loss:0.03207, Train_acc:0.98555
# #train_set:1, loss:0.03503, Train_acc:0.98594
# #train_set:2, loss:0.08420, Train_acc:0.98633
# #train_set:3, loss:0.04160, Train_acc:0.98633
# avg loss:0.04822
# Test_acc:0.97485
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      1297
#            1       0.97      0.98      0.97       218
#            2       0.87      0.83      0.85       133
#            3       0.85      0.93      0.89       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.97      2624
#    macro avg       0.94      0.95      0.95      2624
# weighted avg       0.98      0.97      0.98      2624
#
# Time span:2998.59774
# ===>epoch:050===>
# #train_set:0, loss:0.03425, Train_acc:0.98594
# #train_set:1, loss:0.02766, Train_acc:0.98945
# #train_set:2, loss:0.03290, Train_acc:0.98594
# #train_set:3, loss:0.03174, Train_acc:0.98828
# avg loss:0.03164
# Test_acc:0.97675
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1297
#            1       1.00      0.96      0.98       218
#            2       0.88      0.81      0.84       133
#            3       0.87      0.92      0.89       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.98      2624
#    macro avg       0.95      0.94      0.95      2624
# weighted avg       0.98      0.98      0.98      2624
#
# Time span:3060.25554
# ===>epoch:051===>
# #train_set:0, loss:0.03413, Train_acc:0.98867
# #train_set:1, loss:0.02755, Train_acc:0.99062
# #train_set:2, loss:0.03149, Train_acc:0.98945
# #train_set:3, loss:0.03218, Train_acc:0.98672
# avg loss:0.03134
# Test_acc:0.97599
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      1297
#            1       1.00      0.95      0.98       218
#            2       0.87      0.81      0.84       133
#            3       0.87      0.93      0.90       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.98      2624
#    macro avg       0.95      0.95      0.95      2624
# weighted avg       0.98      0.98      0.98      2624
#
# Time span:3122.15271
# ===>epoch:052===>
# #train_set:0, loss:0.03367, Train_acc:0.98945
# #train_set:1, loss:0.08194, Train_acc:0.98555
# #train_set:2, loss:0.08190, Train_acc:0.98281
# #train_set:3, loss:0.07949, Train_acc:0.98281
# avg loss:0.06925
# Test_acc:0.96875
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      1297
#            1       0.97      0.97      0.97       218
#            2       0.79      0.84      0.82       133
#            3       0.88      0.83      0.86       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.97      0.99       154
#
#     accuracy                           0.97      2624
#    macro avg       0.94      0.93      0.93      2624
# weighted avg       0.97      0.97      0.97      2624
#
# Time span:3184.17687
# ===>epoch:053===>
# #train_set:0, loss:0.05543, Train_acc:0.98281
# #train_set:1, loss:0.04598, Train_acc:0.98320
# #train_set:2, loss:0.04064, Train_acc:0.98516
# #train_set:3, loss:0.03300, Train_acc:0.98828
# avg loss:0.04376
# Test_acc:0.97790
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      1297
#            1       1.00      0.95      0.98       218
#            2       0.89      0.83      0.86       133
#            3       0.88      0.94      0.91       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.98      2624
#    macro avg       0.96      0.95      0.95      2624
# weighted avg       0.98      0.98      0.98      2624
#
# Time span:3245.05466
# ===>epoch:054===>
# #train_set:0, loss:0.03087, Train_acc:0.98867
# #train_set:1, loss:0.03142, Train_acc:0.98867
# #train_set:2, loss:0.02860, Train_acc:0.98867
# #train_set:3, loss:0.02680, Train_acc:0.98711
# avg loss:0.02942
# Test_acc:0.97675
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      1297
#            1       1.00      0.95      0.98       218
#            2       0.90      0.80      0.84       133
#            3       0.85      0.97      0.90       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.98      2624
#    macro avg       0.95      0.95      0.95      2624
# weighted avg       0.98      0.98      0.98      2624
#
# Time span:3305.96960
# ===>epoch:055===>
# #train_set:0, loss:0.03165, Train_acc:0.98555
# #train_set:1, loss:0.03452, Train_acc:0.98828
# #train_set:2, loss:0.03053, Train_acc:0.98867
# #train_set:3, loss:0.03250, Train_acc:0.98867
# avg loss:0.03230
# Test_acc:0.97904
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      1297
#            1       1.00      0.95      0.98       218
#            2       0.84      0.93      0.89       133
#            3       0.93      0.90      0.91       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.98      2624
#    macro avg       0.96      0.96      0.96      2624
# weighted avg       0.98      0.98      0.98      2624
#
# Time span:3366.42820
# ===>epoch:056===>
# #train_set:0, loss:0.02937, Train_acc:0.98633
# #train_set:1, loss:0.02617, Train_acc:0.98516
# #train_set:2, loss:0.02639, Train_acc:0.98945
# #train_set:3, loss:0.02911, Train_acc:0.98906
# avg loss:0.02776
# Test_acc:0.97980
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      1297
#            1       1.00      0.95      0.98       218
#            2       0.91      0.85      0.88       133
#            3       0.88      0.97      0.92       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.98      2624
#    macro avg       0.96      0.96      0.96      2624
# weighted avg       0.98      0.98      0.98      2624
#
# Time span:3426.51032
# ===>epoch:057===>
# #train_set:0, loss:0.02921, Train_acc:0.98672
# #train_set:1, loss:0.10608, Train_acc:0.98125
# #train_set:2, loss:0.07488, Train_acc:0.97578
# #train_set:3, loss:0.04249, Train_acc:0.98789
# avg loss:0.06316
# Test_acc:0.97523
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      1297
#            1       1.00      0.95      0.98       218
#            2       0.87      0.83      0.85       133
#            3       0.88      0.92      0.89       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.98      2624
#    macro avg       0.95      0.95      0.95      2624
# weighted avg       0.98      0.98      0.98      2624
#
# Time span:3486.51881
# ===>epoch:058===>
# #train_set:0, loss:0.04363, Train_acc:0.98633
# #train_set:1, loss:0.05251, Train_acc:0.98555
# ...
#            2       0.93      0.86      0.89       133
#            3       0.89      0.97      0.93       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.98      2624
#    macro avg       0.97      0.96      0.96      2624
# weighted avg       0.98      0.98      0.98      2624
#
# Time span:3668.20431
# ===>epoch:061===>
# #train_set:0, loss:0.02723, Train_acc:0.98945
# #train_set:1, loss:0.02706, Train_acc:0.98828
# #train_set:2, loss:0.03798, Train_acc:0.98086
# #train_set:3, loss:0.07893, Train_acc:0.97578
# avg loss:0.04280
# Test_acc:0.96570
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      1297
#            1       1.00      0.93      0.96       218
#            2       0.94      0.61      0.74       133
#            3       0.91      0.93      0.92       153
#            4       0.98      0.99      0.99       669
#            5       0.89      0.99      0.94       154
#
#     accuracy                           0.97      2624
#    macro avg       0.95      0.91      0.92      2624
# weighted avg       0.97      0.97      0.96      2624
#
# Time span:3728.49155
# ===>epoch:062===>
# #train_set:0, loss:0.21761, Train_acc:0.98438
# #train_set:1, loss:0.04836, Train_acc:0.98828
# #train_set:2, loss:0.03790, Train_acc:0.98516
# #train_set:3, loss:0.09054, Train_acc:0.98242
# avg loss:0.09860
# Test_acc:0.97332
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      1297
#            1       0.95      1.00      0.97       218
#            2       0.83      0.87      0.85       133
#            3       0.95      0.82      0.88       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.98      0.99       154
#
#     accuracy                           0.97      2624
#    macro avg       0.95      0.94      0.95      2624
# weighted avg       0.97      0.97      0.97      2624
#
# Time span:3788.99653
# ===>epoch:063===>
# #train_set:0, loss:0.03386, Train_acc:0.98633
# #train_set:1, loss:0.03092, Train_acc:0.99102
# #train_set:2, loss:0.07262, Train_acc:0.98008
# #train_set:3, loss:0.03581, Train_acc:0.98828
# avg loss:0.04330
# Test_acc:0.97523
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      1297
#            1       1.00      0.95      0.98       218
#            2       0.90      0.77      0.83       133
#            3       0.88      0.93      0.90       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.98      2624
#    macro avg       0.96      0.94      0.95      2624
# weighted avg       0.98      0.98      0.97      2624
#
# Time span:3849.20592
# ===>epoch:064===>
# #train_set:0, loss:0.02671, Train_acc:0.98828
# #train_set:1, loss:0.02875, Train_acc:0.98594
# #train_set:2, loss:0.02974, Train_acc:0.98594
# #train_set:3, loss:0.02917, Train_acc:0.98789
# avg loss:0.02859
# Test_acc:0.97675
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      1297
#            1       1.00      0.95      0.98       218
#            2       0.89      0.81      0.85       133
#            3       0.88      0.94      0.91       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.98      2624
#    macro avg       0.96      0.95      0.95      2624
# weighted avg       0.98      0.98      0.98      2624
#
# Time span:3909.64366
# ===>epoch:065===>
# #train_set:0, loss:0.02757, Train_acc:0.98828
# #train_set:1, loss:0.02950, Train_acc:0.98711
# #train_set:2, loss:0.02650, Train_acc:0.98789
# #train_set:3, loss:0.02550, Train_acc:0.98711
# avg loss:0.02726
# Test_acc:0.97828
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      1297
#            1       1.00      0.95      0.98       218
#            2       0.85      0.90      0.87       133
#            3       0.92      0.88      0.90       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.98      2624
#    macro avg       0.96      0.95      0.96      2624
# weighted avg       0.98      0.98      0.98      2624
#
# Time span:3969.92680
# ===>epoch:066===>
# #train_set:0, loss:0.02917, Train_acc:0.98633
# #train_set:1, loss:0.08905, Train_acc:0.98242
# #train_set:2, loss:0.03802, Train_acc:0.98750
# #train_set:3, loss:0.03428, Train_acc:0.98828
# avg loss:0.04763
# Test_acc:0.97637
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      1297
#            1       1.00      0.95      0.98       218
#            2       0.88      0.80      0.84       133
#            3       0.86      0.95      0.90       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.98      2624
#    macro avg       0.95      0.95      0.95      2624
# weighted avg       0.98      0.98      0.98      2624
#
# Time span:4030.62583
# ===>epoch:067===>
# #train_set:0, loss:0.03947, Train_acc:0.98750
# #train_set:1, loss:0.02930, Train_acc:0.99102
# #train_set:2, loss:0.02787, Train_acc:0.98828
# #train_set:3, loss:0.02599, Train_acc:0.99023
# avg loss:0.03066
# Test_acc:0.97942
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      1297
#            1       1.00      0.95      0.98       218
#            2       0.89      0.86      0.88       133
#            3       0.94      0.94      0.94       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.98      2624
#    macro avg       0.97      0.96      0.96      2624
# weighted avg       0.98      0.98      0.98      2624
#
# Time span:4091.05314
# ===>epoch:068===>
# #train_set:0, loss:0.02692, Train_acc:0.98750
# #train_set:1, loss:0.02521, Train_acc:0.99023
# #train_set:2, loss:0.02881, Train_acc:0.98906
# #train_set:3, loss:0.03131, Train_acc:0.98945
# avg loss:0.02806
# Test_acc:0.97828
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      1297
#            1       1.00      0.95      0.98       218
#            2       0.98      0.76      0.86       133
#            3       0.89      0.96      0.92       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.98      2624
#    macro avg       0.97      0.94      0.96      2624
# weighted avg       0.98      0.98      0.98      2624
#
# Time span:4151.65613
# ===>epoch:069===>
# #train_set:0, loss:0.03369, Train_acc:0.98750
# #train_set:1, loss:0.03114, Train_acc:0.98789
# #train_set:2, loss:0.02750, Train_acc:0.98828
# #train_set:3, loss:0.03573, Train_acc:0.98945
# avg loss:0.03201
# Test_acc:0.97904
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      1297
#            1       1.00      0.95      0.98       218
#            2       0.87      0.88      0.88       133
#            3       0.91      0.92      0.92       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.98      2624
#    macro avg       0.96      0.96      0.96      2624
# weighted avg       0.98      0.98      0.98      2624
#
# Time span:4212.04052
# ===>epoch:070===>
# #train_set:0, loss:0.03250, Train_acc:0.98672
# #train_set:1, loss:0.02438, Train_acc:0.98711
# #train_set:2, loss:0.02809, Train_acc:0.99102
# #train_set:3, loss:0.02305, Train_acc:0.99102
# avg loss:0.02701
# Test_acc:0.97904
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      1297
#            1       1.00      0.95      0.98       218
#            2       0.85      0.91      0.88       133
#            3       0.93      0.88      0.91       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.98      2624
#    macro avg       0.96      0.95      0.96      2624
# weighted avg       0.98      0.98      0.98      2624
#
# Time span:4272.56104
# ===>epoch:071===>
# #train_set:0, loss:0.06534, Train_acc:0.97930
# #train_set:1, loss:0.10101, Train_acc:0.98672
# #train_set:2, loss:0.04456, Train_acc:0.98867
# #train_set:3, loss:0.03376, Train_acc:0.98828
# avg loss:0.06117
# Test_acc:0.97790
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      1297
#            1       1.00      0.95      0.98       218
#            2       0.89      0.83      0.86       133
#            3       0.86      0.96      0.91       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.98      2624
#    macro avg       0.96      0.95      0.95      2624
# weighted avg       0.98      0.98      0.98      2624
#
# Time span:4332.83268
# ===>epoch:072===>
# #train_set:0, loss:0.02910, Train_acc:0.98828
# #train_set:1, loss:0.03094, Train_acc:0.99102
# #train_set:2, loss:0.02954, Train_acc:0.98867
# #train_set:3, loss:0.12634, Train_acc:0.98164
# avg loss:0.05398
# Test_acc:0.97104
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      1297
#            1       0.95      1.00      0.97       218
#            2       0.81      0.81      0.81       133
#            3       0.88      0.85      0.87       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.98      0.99       154
#
#     accuracy                           0.97      2624
#    macro avg       0.94      0.94      0.94      2624
# weighted avg       0.97      0.97      0.97      2624
#
# Time span:4393.22599
# ===>epoch:073===>
# #train_set:0, loss:0.11286, Train_acc:0.98008
# #train_set:1, loss:0.05776, Train_acc:0.98828
# #train_set:2, loss:0.03931, Train_acc:0.98828
# #train_set:3, loss:0.04024, Train_acc:0.98711
# avg loss:0.06254
# Test_acc:0.97866
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1297
#            1       1.00      0.95      0.98       218
#            2       0.90      0.83      0.87       133
#            3       0.93      0.93      0.93       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.98      2624
#    macro avg       0.97      0.95      0.96      2624
# weighted avg       0.98      0.98      0.98      2624
#
# Time span:4455.58043
# ===>epoch:074===>
# #train_set:0, loss:0.03230, Train_acc:0.98945
# #train_set:1, loss:0.06736, Train_acc:0.98086
# #train_set:2, loss:0.04648, Train_acc:0.98906
# #train_set:3, loss:0.02864, Train_acc:0.98945
# avg loss:0.04369
# Test_acc:0.97828
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1297
#            1       1.00      0.95      0.98       218
#            2       0.92      0.80      0.86       133
#            3       0.90      0.95      0.92       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.98      2624
#    macro avg       0.97      0.95      0.96      2624
# weighted avg       0.98      0.98      0.98      2624
#
# Time span:4520.08022
# ===>epoch:075===>
# #train_set:0, loss:0.02928, Train_acc:0.98828
# #train_set:1, loss:0.03555, Train_acc:0.98594
# #train_set:2, loss:0.05002, Train_acc:0.98828
# #train_set:3, loss:0.03090, Train_acc:0.99023
# avg loss:0.03644
# Test_acc:0.97790
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1297
#            1       1.00      0.95      0.98       218
#            2       0.88      0.84      0.86       133
#            3       0.92      0.91      0.91       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.98      2624
#    macro avg       0.96      0.95      0.96      2624
# weighted avg       0.98      0.98      0.98      2624
#
# Time span:4588.05250
# ===>epoch:076===>
# #train_set:0, loss:0.02604, Train_acc:0.98906
# #train_set:1, loss:0.02326, Train_acc:0.99141
# #train_set:2, loss:0.02527, Train_acc:0.98945
# #train_set:3, loss:0.02576, Train_acc:0.98867
# avg loss:0.02508
# Test_acc:0.98361
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      1297
#            1       1.00      0.95      0.98       218
#            2       0.91      0.94      0.92       133
#            3       0.96      0.93      0.95       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.98      2624
#    macro avg       0.97      0.97      0.97      2624
# weighted avg       0.98      0.98      0.98      2624
#
# Time span:4653.03539
# ===>epoch:077===>
# #train_set:0, loss:0.02506, Train_acc:0.98828
# #train_set:1, loss:0.02303, Train_acc:0.99141
# #train_set:2, loss:0.03299, Train_acc:0.98906
# #train_set:3, loss:0.02592, Train_acc:0.98945
# avg loss:0.02675
# Test_acc:0.97790
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1297
#            1       1.00      0.95      0.98       218
#            2       0.94      0.77      0.85       133
#            3       0.88      0.97      0.92       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.98      2624
#    macro avg       0.97      0.95      0.95      2624
# weighted avg       0.98      0.98      0.98      2624
#
# Time span:4717.76391
# ===>epoch:078===>
# #train_set:0, loss:0.02317, Train_acc:0.99023
# #train_set:1, loss:0.02202, Train_acc:0.99141
# #train_set:2, loss:0.02230, Train_acc:0.98906
# #train_set:3, loss:0.02472, Train_acc:0.99141
# avg loss:0.02305
# Test_acc:0.98171
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1297
#            1       1.00      0.95      0.98       218
#            2       0.93      0.87      0.90       133
#            3       0.94      0.95      0.94       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.98      2624
#    macro avg       0.97      0.96      0.97      2624
# weighted avg       0.98      0.98      0.98      2624
#
# Time span:4782.76152
# ===>epoch:079===>
# #train_set:0, loss:0.02524, Train_acc:0.98906
# #train_set:1, loss:0.02127, Train_acc:0.99141
# #train_set:2, loss:0.02706, Train_acc:0.99102
# #train_set:3, loss:0.03070, Train_acc:0.98984
# avg loss:0.02607
# Test_acc:0.98018
# measure_result =
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1297
#            1       1.00      0.95      0.98       218
#            2       0.93      0.86      0.90       133
#            3       0.93      0.93      0.93       153
#            4       1.00      0.99      0.99       669
#            5       1.00      0.99      1.00       154
#
#     accuracy                           0.98      2624
#    macro avg       0.97      0.95      0.96      2624
# weighted avg       0.98      0.98      0.98      2624
#
# Time span:4847.69463
# Total time span:4847.69563

# %%
# show res
print("best acc:{:.5f}, at epoch:{:3d}".format(best_acc['acc'], best_acc['epoch']))
# Out:
# best acc:0.98361, at epoch: 76

# %%
x = np.arange(0, 320, 1)
plt.title("all_loss for each train_file")
plt.xlabel("iteration * #train_file")
plt.ylabel("train loss")
plt.plot(x, all_loss_list)

# %%
x = np.arange(0, 80, 1)
plt.title("avg_loss for each epoch")
plt.xlabel("iteration")
plt.ylabel("train loss")
plt.plot(x, avg_loss_list)

# %%
x = np.arange(0, 80, 1)
plt.title("acc for each epoch")
plt.xlabel("iteration")
plt.ylabel("test loss")
plt.plot(x, acc_list)
